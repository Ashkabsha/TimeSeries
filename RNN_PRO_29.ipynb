# %% [markdown]
# <a href="https://colab.research.google.com/github/Ashkabsha/TimeSeries/blob/main/RNN_PRO_29.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Importing Packages

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import SimpleRNN
from keras.layers import Dropout
import yfinance as yf
from keras.initializers import RandomNormal

# %%
stock_symbol = 'TSLA'
df = yf.download(stock_symbol,period="60mo",interval="1d")
print(df.head())
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                  Open       High        Low      Close  Adj Close     Volume
# Date
# 2018-11-29  23.133333  23.166668  22.636667  22.744667  22.744667   46210500
# 2018-11-30  22.788668  23.440001  22.550667  23.365334  23.365334   84436500
# 2018-12-03  24.000000  24.400000  23.466667  23.899332  23.899332  124597500
# 2018-12-04  23.736668  24.578667  23.466667  23.980000  23.980000  126928500
# 2018-12-06  23.733999  24.492001  23.384001  24.204000  24.204000  117637500

# %% [markdown]
# Importing Data

# %%
df.index = df.index.strftime('%Y-%m-%d')

# %%
df
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2018-11-29   23.133333   23.166668   22.636667   22.744667   22.744667
# 2018-11-30   22.788668   23.440001   22.550667   23.365334   23.365334
# 2018-12-03   24.000000   24.400000   23.466667   23.899332   23.899332
# 2018-12-04   23.736668   24.578667   23.466667   23.980000   23.980000
# 2018-12-06   23.733999   24.492001   23.384001   24.204000   24.204000
# ...                ...         ...         ...         ...         ...
# 2023-11-22  242.039993  244.009995  231.399994  234.210007  234.210007
# 2023-11-24  233.750000  238.750000  232.330002  235.449997  235.449997
# 2023-11-27  236.889999  238.330002  232.100006  236.080002  236.080002
# 2023-11-28  236.679993  247.000000  234.009995  246.720001  246.720001
# 2023-11-29  249.210007  252.750000  247.720001  250.434998  250.434998
#
#                Volume
# Date
# 2018-11-29   46210500
# 2018-11-30   84436500
# 2018-12-03  124597500
# 2018-12-04  126928500
# 2018-12-06  117637500
# ...               ...
# 2023-11-22  117950600
# 2023-11-24   65125200
# 2023-11-27  112031800
# 2023-11-28  147829500
# 2023-11-29   36778425
#
# [1258 rows x 6 columns]

# %%
len(df)
# Out:
# 1258

# %%
df['Open'].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
b_size=32
epoch=200
train_per=0.8
w_size=30
f_size=10

# %%
t_size=int(len(df)*train_per)

# %% [markdown]
# Train-Test Split

# %% [markdown]
# Normalization

# %%
sc = MinMaxScaler(feature_range = (0, 1))

# %% [markdown]
# Create target values

# %%
data_train = df.iloc[:t_size, 1:2].values
data_test = df.iloc[t_size:, 1:2].values
data_total = df.iloc[:,1:2]#open price
sc = MinMaxScaler(feature_range = (0, 1))
training_scaled = sc.fit_transform(data_train)

#Train Data
x_train = []
y_train = []
for iter in range(w_size, t_size):
    x_train.append(training_scaled[iter-w_size:iter, 0])
    y_train.append(training_scaled[iter, 0])
x_train, y_train=np.array(x_train), np.array(y_train)
x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))


#Test data
total_input = data_total[len(data_total) - len(data_test) - w_size:].values
total_input = total_input.reshape(-1, 1)
total_input = sc.transform(total_input)
x_test = []
y_test=[]

# Calculate the maximum number of blocks of length w_size that can be created
blocks = len(total_input) - w_size

for iter in range(blocks):
    x_test.append(total_input[iter:iter+w_size, 0])
    y_test.append(total_input[iter+w_size, 0])     #new addition

x_test = np.array(x_test)
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1))

# %% [markdown]
# Defining Model

# %%
initializer = RandomNormal(mean=0.0, stddev=0.05,seed = 5)
algo = Sequential()
algo.add(SimpleRNN(units=60, return_sequences=True, input_shape=(x_train.shape[1], 1), kernel_initializer=initializer))
algo.add(Dropout(0.2))
algo.add(SimpleRNN(units=60))

algo.add(Dense(units=1))
algo.compile(optimizer = 'adam', loss = 'mean_squared_error')
print(algo.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn (SimpleRNN)      (None, 30, 60)            3720
#
#  dropout (Dropout)           (None, 30, 60)            0
#
#  simple_rnn_1 (SimpleRNN)    (None, 60)                7260
#
#  dense (Dense)               (None, 1)                 61
#
# =================================================================
# Total params: 11041 (43.13 KB)
# Trainable params: 11041 (43.13 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None

# %% [markdown]
# Training Model

# %%
algo.fit(x_train, y_train, epochs = epoch, batch_size = b_size, validation_split=0.15,verbose=2)
# Out:
# Epoch 1/200
# 26/26 - 14s - loss: 0.0388 - val_loss: 0.0089 - 14s/epoch - 538ms/step
# Epoch 2/200
# 26/26 - 3s - loss: 0.0061 - val_loss: 0.0079 - 3s/epoch - 114ms/step
# Epoch 3/200
# 26/26 - 3s - loss: 0.0045 - val_loss: 0.0052 - 3s/epoch - 117ms/step
# Epoch 4/200
# 26/26 - 2s - loss: 0.0041 - val_loss: 0.0032 - 2s/epoch - 86ms/step
# Epoch 5/200
# 26/26 - 1s - loss: 0.0033 - val_loss: 0.0041 - 1s/epoch - 49ms/step
# Epoch 6/200
# 26/26 - 1s - loss: 0.0028 - val_loss: 0.0027 - 1s/epoch - 42ms/step
# Epoch 7/200
# 26/26 - 1s - loss: 0.0028 - val_loss: 0.0041 - 1s/epoch - 43ms/step
# Epoch 8/200
# 26/26 - 1s - loss: 0.0030 - val_loss: 0.0028 - 1s/epoch - 44ms/step
# Epoch 9/200
# 26/26 - 1s - loss: 0.0019 - val_loss: 0.0019 - 1s/epoch - 44ms/step
# Epoch 10/200
# 26/26 - 1s - loss: 0.0020 - val_loss: 0.0018 - 1s/epoch - 44ms/step
# Epoch 11/200
# 26/26 - 1s - loss: 0.0018 - val_loss: 0.0043 - 1s/epoch - 44ms/step
# Epoch 12/200
# 26/26 - 1s - loss: 0.0019 - val_loss: 0.0021 - 1s/epoch - 44ms/step
# Epoch 13/200
# 26/26 - 1s - loss: 0.0023 - val_loss: 0.0059 - 1s/epoch - 44ms/step
# Epoch 14/200
# 26/26 - 2s - loss: 0.0017 - val_loss: 0.0015 - 2s/epoch - 92ms/step
# Epoch 15/200
# 26/26 - 2s - loss: 0.0019 - val_loss: 0.0014 - 2s/epoch - 66ms/step
# Epoch 16/200
# 26/26 - 1s - loss: 0.0013 - val_loss: 0.0022 - 1s/epoch - 44ms/step
# Epoch 17/200
# 26/26 - 1s - loss: 0.0014 - val_loss: 0.0037 - 1s/epoch - 50ms/step
# Epoch 18/200
# 26/26 - 1s - loss: 0.0012 - val_loss: 0.0020 - 1s/epoch - 42ms/step
# Epoch 19/200
# 26/26 - 1s - loss: 0.0013 - val_loss: 0.0012 - 1s/epoch - 42ms/step
# Epoch 20/200
# 26/26 - 1s - loss: 0.0016 - val_loss: 0.0012 - 1s/epoch - 47ms/step
# Epoch 21/200
# 26/26 - 1s - loss: 0.0013 - val_loss: 0.0014 - 1s/epoch - 41ms/step
# Epoch 22/200
# 26/26 - 1s - loss: 0.0012 - val_loss: 0.0013 - 1s/epoch - 44ms/step
# Epoch 23/200
# 26/26 - 1s - loss: 0.0012 - val_loss: 0.0013 - 1s/epoch - 42ms/step
# Epoch 24/200
# 26/26 - 2s - loss: 0.0012 - val_loss: 0.0026 - 2s/epoch - 76ms/step
# Epoch 25/200
# 26/26 - 2s - loss: 0.0010 - val_loss: 0.0012 - 2s/epoch - 79ms/step
# Epoch 26/200
# 26/26 - 1s - loss: 0.0011 - val_loss: 0.0011 - 1s/epoch - 44ms/step
# Epoch 27/200
# 26/26 - 1s - loss: 0.0015 - val_loss: 0.0014 - 1s/epoch - 43ms/step
# Epoch 28/200
# 26/26 - 1s - loss: 0.0017 - val_loss: 0.0010 - 1s/epoch - 41ms/step
# Epoch 29/200
# 26/26 - 1s - loss: 0.0011 - val_loss: 0.0019 - 1s/epoch - 42ms/step
# Epoch 30/200
# 26/26 - 1s - loss: 0.0012 - val_loss: 0.0028 - 1s/epoch - 45ms/step
# Epoch 31/200
# 26/26 - 1s - loss: 0.0010 - val_loss: 0.0010 - 1s/epoch - 43ms/step
# Epoch 32/200
# 26/26 - 1s - loss: 9.9288e-04 - val_loss: 0.0011 - 1s/epoch - 48ms/step
# Epoch 33/200
# 26/26 - 1s - loss: 0.0012 - val_loss: 0.0017 - 1s/epoch - 42ms/step
# Epoch 34/200
# 26/26 - 1s - loss: 0.0011 - val_loss: 0.0015 - 1s/epoch - 50ms/step
# Epoch 35/200
# 26/26 - 2s - loss: 9.0505e-04 - val_loss: 0.0010 - 2s/epoch - 86ms/step
# Epoch 36/200
# 26/26 - 2s - loss: 9.3293e-04 - val_loss: 0.0010 - 2s/epoch - 58ms/step
# Epoch 37/200
# 26/26 - 1s - loss: 9.5183e-04 - val_loss: 0.0011 - 1s/epoch - 42ms/step
# Epoch 38/200
# 26/26 - 1s - loss: 0.0011 - val_loss: 0.0025 - 1s/epoch - 43ms/step
# Epoch 39/200
# 26/26 - 1s - loss: 8.6818e-04 - val_loss: 9.6693e-04 - 1s/epoch - 43ms/step
# Epoch 40/200
# 26/26 - 1s - loss: 8.7692e-04 - val_loss: 0.0010 - 1s/epoch - 44ms/step
# Epoch 41/200
# 26/26 - 1s - loss: 8.8327e-04 - val_loss: 9.5377e-04 - 1s/epoch - 43ms/step
# Epoch 42/200
# 26/26 - 1s - loss: 7.4925e-04 - val_loss: 0.0019 - 1s/epoch - 43ms/step
# Epoch 43/200
# 26/26 - 1s - loss: 8.2805e-04 - val_loss: 0.0012 - 1s/epoch - 44ms/step
# Epoch 44/200
# 26/26 - 1s - loss: 8.7923e-04 - val_loss: 0.0012 - 1s/epoch - 44ms/step
# Epoch 45/200
# 26/26 - 2s - loss: 9.5735e-04 - val_loss: 0.0017 - 2s/epoch - 80ms/step
# Epoch 46/200
# 26/26 - 2s - loss: 9.9115e-04 - val_loss: 0.0013 - 2s/epoch - 84ms/step
# Epoch 47/200
# 26/26 - 1s - loss: 8.8111e-04 - val_loss: 0.0022 - 1s/epoch - 43ms/step
# Epoch 48/200
# 26/26 - 1s - loss: 9.8758e-04 - val_loss: 0.0021 - 1s/epoch - 44ms/step
# Epoch 49/200
# 26/26 - 1s - loss: 7.9184e-04 - val_loss: 0.0012 - 1s/epoch - 43ms/step
# Epoch 50/200
# 26/26 - 1s - loss: 7.5923e-04 - val_loss: 0.0010 - 1s/epoch - 41ms/step
# Epoch 51/200
# 26/26 - 1s - loss: 6.8822e-04 - val_loss: 8.1900e-04 - 1s/epoch - 43ms/step
# Epoch 52/200
# 26/26 - 1s - loss: 6.2420e-04 - val_loss: 8.7671e-04 - 1s/epoch - 44ms/step
# Epoch 53/200
# 26/26 - 1s - loss: 7.2713e-04 - val_loss: 8.1815e-04 - 1s/epoch - 45ms/step
# Epoch 54/200
# 26/26 - 1s - loss: 7.3354e-04 - val_loss: 8.3006e-04 - 1s/epoch - 43ms/step
# Epoch 55/200
# 26/26 - 1s - loss: 8.3100e-04 - val_loss: 7.8679e-04 - 1s/epoch - 52ms/step
# Epoch 56/200
# 26/26 - 2s - loss: 6.7063e-04 - val_loss: 0.0011 - 2s/epoch - 89ms/step
# Epoch 57/200
# 26/26 - 1s - loss: 7.8953e-04 - val_loss: 8.6579e-04 - 1s/epoch - 57ms/step
# Epoch 58/200
# 26/26 - 1s - loss: 6.6133e-04 - val_loss: 0.0011 - 1s/epoch - 43ms/step
# Epoch 59/200
# 26/26 - 1s - loss: 6.3094e-04 - val_loss: 0.0016 - 1s/epoch - 42ms/step
# Epoch 60/200
# 26/26 - 1s - loss: 9.3332e-04 - val_loss: 8.3769e-04 - 1s/epoch - 44ms/step
# Epoch 61/200
# 26/26 - 1s - loss: 9.1661e-04 - val_loss: 8.6554e-04 - 1s/epoch - 42ms/step
# Epoch 62/200
# 26/26 - 1s - loss: 7.2274e-04 - val_loss: 7.4890e-04 - 1s/epoch - 50ms/step
# Epoch 63/200
# 26/26 - 1s - loss: 6.7121e-04 - val_loss: 9.9024e-04 - 1s/epoch - 41ms/step
# Epoch 64/200
# 26/26 - 1s - loss: 8.5094e-04 - val_loss: 8.8673e-04 - 1s/epoch - 42ms/step
# Epoch 65/200
# 26/26 - 1s - loss: 7.1444e-04 - val_loss: 0.0010 - 1s/epoch - 43ms/step
# Epoch 66/200
# 26/26 - 2s - loss: 6.4694e-04 - val_loss: 9.2662e-04 - 2s/epoch - 78ms/step
# Epoch 67/200
# 26/26 - 2s - loss: 6.9584e-04 - val_loss: 7.2875e-04 - 2s/epoch - 79ms/step
# Epoch 68/200
# 26/26 - 1s - loss: 6.5736e-04 - val_loss: 0.0023 - 1s/epoch - 39ms/step
# Epoch 69/200
# 26/26 - 1s - loss: 8.1259e-04 - val_loss: 0.0010 - 1s/epoch - 41ms/step
# Epoch 70/200
# 26/26 - 1s - loss: 9.3445e-04 - val_loss: 0.0011 - 1s/epoch - 50ms/step
# Epoch 71/200
# 26/26 - 2s - loss: 6.6133e-04 - val_loss: 9.2563e-04 - 2s/epoch - 79ms/step
# Epoch 72/200
# 26/26 - 1s - loss: 5.8721e-04 - val_loss: 6.6935e-04 - 1s/epoch - 44ms/step
# Epoch 73/200
# 26/26 - 1s - loss: 6.1513e-04 - val_loss: 6.7252e-04 - 1s/epoch - 44ms/step
# Epoch 74/200
# 26/26 - 1s - loss: 6.9480e-04 - val_loss: 6.8846e-04 - 1s/epoch - 43ms/step
# Epoch 75/200
# 26/26 - 1s - loss: 5.9838e-04 - val_loss: 0.0017 - 1s/epoch - 51ms/step
# Epoch 76/200
# 26/26 - 2s - loss: 8.1760e-04 - val_loss: 7.3393e-04 - 2s/epoch - 91ms/step
# Epoch 77/200
# 26/26 - 1s - loss: 6.0112e-04 - val_loss: 6.2849e-04 - 1s/epoch - 58ms/step
# Epoch 78/200
# 26/26 - 1s - loss: 5.5141e-04 - val_loss: 7.6277e-04 - 1s/epoch - 41ms/step
# Epoch 79/200
# 26/26 - 1s - loss: 5.6360e-04 - val_loss: 9.2868e-04 - 1s/epoch - 43ms/step
# Epoch 80/200
# 26/26 - 1s - loss: 5.5506e-04 - val_loss: 7.1845e-04 - 1s/epoch - 46ms/step
# Epoch 81/200
# 26/26 - 1s - loss: 6.4825e-04 - val_loss: 7.3180e-04 - 1s/epoch - 41ms/step
# Epoch 82/200
# 26/26 - 1s - loss: 6.9469e-04 - val_loss: 6.1602e-04 - 1s/epoch - 42ms/step
# Epoch 83/200
# 26/26 - 1s - loss: 6.9228e-04 - val_loss: 9.2458e-04 - 1s/epoch - 46ms/step
# Epoch 84/200
# 26/26 - 1s - loss: 6.9627e-04 - val_loss: 6.5967e-04 - 1s/epoch - 44ms/step
# Epoch 85/200
# 26/26 - 1s - loss: 6.3960e-04 - val_loss: 9.9657e-04 - 1s/epoch - 44ms/step
# Epoch 86/200
# 26/26 - 2s - loss: 7.1844e-04 - val_loss: 0.0011 - 2s/epoch - 77ms/step
# Epoch 87/200
# 26/26 - 2s - loss: 6.4884e-04 - val_loss: 0.0013 - 2s/epoch - 79ms/step
# Epoch 88/200
# 26/26 - 1s - loss: 6.4617e-04 - val_loss: 9.8196e-04 - 1s/epoch - 43ms/step
# Epoch 89/200
# 26/26 - 1s - loss: 5.6268e-04 - val_loss: 6.1705e-04 - 1s/epoch - 45ms/step
# Epoch 90/200
# 26/26 - 1s - loss: 5.3535e-04 - val_loss: 6.2502e-04 - 1s/epoch - 41ms/step
# Epoch 91/200
# 26/26 - 1s - loss: 5.8032e-04 - val_loss: 9.7226e-04 - 1s/epoch - 44ms/step
# Epoch 92/200
# 26/26 - 1s - loss: 6.3592e-04 - val_loss: 6.0826e-04 - 1s/epoch - 42ms/step
# Epoch 93/200
# 26/26 - 1s - loss: 7.0037e-04 - val_loss: 6.7097e-04 - 1s/epoch - 42ms/step
# Epoch 94/200
# 26/26 - 1s - loss: 8.4445e-04 - val_loss: 8.8848e-04 - 1s/epoch - 43ms/step
# Epoch 95/200
# 26/26 - 1s - loss: 8.3986e-04 - val_loss: 0.0012 - 1s/epoch - 47ms/step
# Epoch 96/200
# 26/26 - 2s - loss: 6.3595e-04 - val_loss: 5.7946e-04 - 2s/epoch - 60ms/step
# Epoch 97/200
# 26/26 - 2s - loss: 5.7790e-04 - val_loss: 0.0011 - 2s/epoch - 86ms/step
# Epoch 98/200
# 26/26 - 1s - loss: 5.5440e-04 - val_loss: 5.6992e-04 - 1s/epoch - 51ms/step
# Epoch 99/200
# 26/26 - 1s - loss: 5.8329e-04 - val_loss: 9.1501e-04 - 1s/epoch - 44ms/step
# Epoch 100/200
# 26/26 - 1s - loss: 6.4707e-04 - val_loss: 5.9780e-04 - 1s/epoch - 45ms/step
# Epoch 101/200
# 26/26 - 1s - loss: 5.6285e-04 - val_loss: 0.0014 - 1s/epoch - 45ms/step
# Epoch 102/200
# 26/26 - 1s - loss: 6.2583e-04 - val_loss: 5.8222e-04 - 1s/epoch - 42ms/step
# Epoch 103/200
# 26/26 - 1s - loss: 6.2500e-04 - val_loss: 6.0385e-04 - 1s/epoch - 45ms/step
# Epoch 104/200
# 26/26 - 1s - loss: 5.1267e-04 - val_loss: 6.8890e-04 - 1s/epoch - 43ms/step
# Epoch 105/200
# 26/26 - 1s - loss: 6.4862e-04 - val_loss: 7.2485e-04 - 1s/epoch - 46ms/step
# Epoch 106/200
# 26/26 - 1s - loss: 5.6035e-04 - val_loss: 5.7203e-04 - 1s/epoch - 51ms/step
# Epoch 107/200
# 26/26 - 2s - loss: 5.6097e-04 - val_loss: 6.0454e-04 - 2s/epoch - 89ms/step
# Epoch 108/200
# 26/26 - 2s - loss: 8.6717e-04 - val_loss: 6.8049e-04 - 2s/epoch - 62ms/step
# Epoch 109/200
# 26/26 - 1s - loss: 6.9941e-04 - val_loss: 5.5149e-04 - 1s/epoch - 42ms/step
# Epoch 110/200
# 26/26 - 1s - loss: 5.4520e-04 - val_loss: 5.9022e-04 - 1s/epoch - 47ms/step
# Epoch 111/200
# 26/26 - 1s - loss: 5.4238e-04 - val_loss: 5.7703e-04 - 1s/epoch - 42ms/step
# Epoch 112/200
# 26/26 - 1s - loss: 5.7225e-04 - val_loss: 6.0488e-04 - 1s/epoch - 42ms/step
# Epoch 113/200
# 26/26 - 1s - loss: 5.6956e-04 - val_loss: 8.5630e-04 - 1s/epoch - 46ms/step
# Epoch 114/200
# 26/26 - 1s - loss: 5.9272e-04 - val_loss: 5.6741e-04 - 1s/epoch - 40ms/step
# Epoch 115/200
# 26/26 - 1s - loss: 5.5764e-04 - val_loss: 5.6759e-04 - 1s/epoch - 42ms/step
# Epoch 116/200
# 26/26 - 1s - loss: 4.9746e-04 - val_loss: 6.6871e-04 - 1s/epoch - 43ms/step
# Epoch 117/200
# 26/26 - 2s - loss: 6.0081e-04 - val_loss: 5.6593e-04 - 2s/epoch - 66ms/step
# Epoch 118/200
# 26/26 - 2s - loss: 5.1980e-04 - val_loss: 6.4193e-04 - 2s/epoch - 88ms/step
# Epoch 119/200
# 26/26 - 1s - loss: 4.8662e-04 - val_loss: 6.2373e-04 - 1s/epoch - 44ms/step
# Epoch 120/200
# 26/26 - 1s - loss: 4.7768e-04 - val_loss: 5.3740e-04 - 1s/epoch - 44ms/step
# Epoch 121/200
# 26/26 - 1s - loss: 5.3672e-04 - val_loss: 9.9402e-04 - 1s/epoch - 48ms/step
# Epoch 122/200
# 26/26 - 1s - loss: 6.3546e-04 - val_loss: 8.2449e-04 - 1s/epoch - 45ms/step
# Epoch 123/200
# 26/26 - 1s - loss: 7.2686e-04 - val_loss: 5.1677e-04 - 1s/epoch - 43ms/step
# Epoch 124/200
# 26/26 - 1s - loss: 4.6092e-04 - val_loss: 9.1566e-04 - 1s/epoch - 44ms/step
# Epoch 125/200
# 26/26 - 1s - loss: 5.4952e-04 - val_loss: 8.5525e-04 - 1s/epoch - 43ms/step
# Epoch 126/200
# 26/26 - 1s - loss: 5.0792e-04 - val_loss: 5.2487e-04 - 1s/epoch - 49ms/step
# Epoch 127/200
# 26/26 - 2s - loss: 4.8027e-04 - val_loss: 5.2091e-04 - 2s/epoch - 59ms/step
# Epoch 128/200
# 26/26 - 2s - loss: 7.1663e-04 - val_loss: 5.3647e-04 - 2s/epoch - 87ms/step
# Epoch 129/200
# 26/26 - 1s - loss: 5.8565e-04 - val_loss: 6.0687e-04 - 1s/epoch - 51ms/step
# Epoch 130/200
# 26/26 - 1s - loss: 5.3662e-04 - val_loss: 6.0336e-04 - 1s/epoch - 46ms/step
# Epoch 131/200
# 26/26 - 1s - loss: 5.9879e-04 - val_loss: 5.7212e-04 - 1s/epoch - 46ms/step
# Epoch 132/200
# 26/26 - 1s - loss: 4.9406e-04 - val_loss: 6.1143e-04 - 1s/epoch - 42ms/step
# Epoch 133/200
# 26/26 - 1s - loss: 4.5960e-04 - val_loss: 6.0201e-04 - 1s/epoch - 40ms/step
# Epoch 134/200
# 26/26 - 1s - loss: 5.6073e-04 - val_loss: 5.3825e-04 - 1s/epoch - 44ms/step
# Epoch 135/200
# 26/26 - 1s - loss: 5.2872e-04 - val_loss: 5.0530e-04 - 1s/epoch - 47ms/step
# Epoch 136/200
# 26/26 - 1s - loss: 4.6866e-04 - val_loss: 5.4115e-04 - 1s/epoch - 44ms/step
# Epoch 137/200
# 26/26 - 1s - loss: 6.4511e-04 - val_loss: 0.0019 - 1s/epoch - 46ms/step
# Epoch 138/200
# 26/26 - 2s - loss: 6.2394e-04 - val_loss: 6.6446e-04 - 2s/epoch - 88ms/step
# Epoch 139/200
# 26/26 - 2s - loss: 5.0649e-04 - val_loss: 7.7699e-04 - 2s/epoch - 63ms/step
# Epoch 140/200
# 26/26 - 1s - loss: 5.2820e-04 - val_loss: 4.9571e-04 - 1s/epoch - 47ms/step
# Epoch 141/200
# 26/26 - 1s - loss: 4.9007e-04 - val_loss: 4.9662e-04 - 1s/epoch - 45ms/step
# Epoch 142/200
# 26/26 - 1s - loss: 4.7835e-04 - val_loss: 5.5863e-04 - 1s/epoch - 40ms/step
# Epoch 143/200
# 26/26 - 1s - loss: 5.1612e-04 - val_loss: 5.4344e-04 - 1s/epoch - 43ms/step
# Epoch 144/200
# 26/26 - 1s - loss: 4.7183e-04 - val_loss: 5.0614e-04 - 1s/epoch - 43ms/step
# Epoch 145/200
# 26/26 - 1s - loss: 5.5978e-04 - val_loss: 5.4964e-04 - 1s/epoch - 42ms/step
# Epoch 146/200
# 26/26 - 1s - loss: 5.0725e-04 - val_loss: 5.2117e-04 - 1s/epoch - 40ms/step
# Epoch 147/200
# 26/26 - 1s - loss: 6.0344e-04 - val_loss: 7.0389e-04 - 1s/epoch - 42ms/step
# Epoch 148/200
# 26/26 - 2s - loss: 5.8145e-04 - val_loss: 0.0011 - 2s/epoch - 69ms/step
# Epoch 149/200
# 26/26 - 2s - loss: 5.2726e-04 - val_loss: 7.2159e-04 - 2s/epoch - 82ms/step
# Epoch 150/200
# 26/26 - 1s - loss: 4.6602e-04 - val_loss: 6.5479e-04 - 1s/epoch - 44ms/step
# Epoch 151/200
# 26/26 - 1s - loss: 4.9992e-04 - val_loss: 5.1211e-04 - 1s/epoch - 45ms/step
# Epoch 152/200
# 26/26 - 1s - loss: 5.1933e-04 - val_loss: 0.0011 - 1s/epoch - 43ms/step
# Epoch 153/200
# 26/26 - 1s - loss: 4.9028e-04 - val_loss: 4.9555e-04 - 1s/epoch - 41ms/step
# Epoch 154/200
# 26/26 - 1s - loss: 4.4110e-04 - val_loss: 6.9127e-04 - 1s/epoch - 44ms/step
# Epoch 155/200
# 26/26 - 1s - loss: 6.1599e-04 - val_loss: 7.1518e-04 - 1s/epoch - 43ms/step
# Epoch 156/200
# 26/26 - 1s - loss: 4.4520e-04 - val_loss: 6.8069e-04 - 1s/epoch - 43ms/step
# Epoch 157/200
# 26/26 - 1s - loss: 4.3210e-04 - val_loss: 5.4190e-04 - 1s/epoch - 40ms/step
# Epoch 158/200
# 26/26 - 1s - loss: 5.7087e-04 - val_loss: 8.4319e-04 - 1s/epoch - 41ms/step
# Epoch 159/200
# 26/26 - 2s - loss: 6.2949e-04 - val_loss: 5.1374e-04 - 2s/epoch - 82ms/step
# Epoch 160/200
# 26/26 - 2s - loss: 5.3986e-04 - val_loss: 4.8821e-04 - 2s/epoch - 75ms/step
# Epoch 161/200
# 26/26 - 1s - loss: 4.5149e-04 - val_loss: 5.0991e-04 - 1s/epoch - 43ms/step
# Epoch 162/200
# 26/26 - 1s - loss: 6.3439e-04 - val_loss: 9.4944e-04 - 1s/epoch - 44ms/step
# Epoch 163/200
# 26/26 - 1s - loss: 5.7407e-04 - val_loss: 6.1780e-04 - 1s/epoch - 46ms/step
# Epoch 164/200
# 26/26 - 1s - loss: 5.2990e-04 - val_loss: 7.7442e-04 - 1s/epoch - 42ms/step
# Epoch 165/200
# 26/26 - 1s - loss: 5.0587e-04 - val_loss: 5.0303e-04 - 1s/epoch - 47ms/step
# Epoch 166/200
# 26/26 - 1s - loss: 6.6560e-04 - val_loss: 5.5003e-04 - 1s/epoch - 42ms/step
# Epoch 167/200
# 26/26 - 1s - loss: 6.2129e-04 - val_loss: 5.6351e-04 - 1s/epoch - 45ms/step
# Epoch 168/200
# 26/26 - 1s - loss: 5.4373e-04 - val_loss: 5.3406e-04 - 1s/epoch - 43ms/step
# Epoch 169/200
# 26/26 - 2s - loss: 4.9257e-04 - val_loss: 4.8961e-04 - 2s/epoch - 62ms/step
# Epoch 170/200
# 26/26 - 2s - loss: 4.8650e-04 - val_loss: 6.6413e-04 - 2s/epoch - 88ms/step
# Epoch 171/200
# 26/26 - 1s - loss: 4.4138e-04 - val_loss: 5.0997e-04 - 1s/epoch - 49ms/step
# Epoch 172/200
# 26/26 - 1s - loss: 4.6637e-04 - val_loss: 5.1502e-04 - 1s/epoch - 43ms/step
# Epoch 173/200
# 26/26 - 1s - loss: 4.7562e-04 - val_loss: 4.9397e-04 - 1s/epoch - 42ms/step
# Epoch 174/200
# 26/26 - 1s - loss: 4.1590e-04 - val_loss: 5.4444e-04 - 1s/epoch - 44ms/step
# Epoch 175/200
# 26/26 - 1s - loss: 4.7404e-04 - val_loss: 5.1754e-04 - 1s/epoch - 42ms/step
# Epoch 176/200
# 26/26 - 1s - loss: 4.1327e-04 - val_loss: 6.7685e-04 - 1s/epoch - 47ms/step
# Epoch 177/200
# 26/26 - 1s - loss: 4.9629e-04 - val_loss: 4.9893e-04 - 1s/epoch - 45ms/step
# Epoch 178/200
# 26/26 - 1s - loss: 5.4685e-04 - val_loss: 5.1705e-04 - 1s/epoch - 40ms/step
# Epoch 179/200
# 26/26 - 1s - loss: 5.1955e-04 - val_loss: 0.0012 - 1s/epoch - 45ms/step
# Epoch 180/200
# 26/26 - 2s - loss: 6.2444e-04 - val_loss: 4.8192e-04 - 2s/epoch - 90ms/step
# Epoch 181/200
# 26/26 - 2s - loss: 4.8638e-04 - val_loss: 8.2910e-04 - 2s/epoch - 64ms/step
# Epoch 182/200
# 26/26 - 1s - loss: 6.5806e-04 - val_loss: 7.2428e-04 - 1s/epoch - 51ms/step
# Epoch 183/200
# 26/26 - 1s - loss: 5.6677e-04 - val_loss: 4.8794e-04 - 1s/epoch - 50ms/step
# Epoch 184/200
# 26/26 - 1s - loss: 5.0206e-04 - val_loss: 5.1069e-04 - 1s/epoch - 41ms/step
# Epoch 185/200
# 26/26 - 1s - loss: 4.3734e-04 - val_loss: 4.8448e-04 - 1s/epoch - 45ms/step
# Epoch 186/200
# 26/26 - 1s - loss: 4.4943e-04 - val_loss: 4.7237e-04 - 1s/epoch - 42ms/step
# Epoch 187/200
# 26/26 - 1s - loss: 6.4465e-04 - val_loss: 7.1934e-04 - 1s/epoch - 48ms/step
# Epoch 188/200
# 26/26 - 1s - loss: 5.2020e-04 - val_loss: 0.0011 - 1s/epoch - 46ms/step
# Epoch 189/200
# 26/26 - 1s - loss: 5.7218e-04 - val_loss: 4.9373e-04 - 1s/epoch - 48ms/step
# Epoch 190/200
# 26/26 - 2s - loss: 4.3761e-04 - val_loss: 8.2608e-04 - 2s/epoch - 88ms/step
# Epoch 191/200
# 26/26 - 2s - loss: 4.2927e-04 - val_loss: 4.7676e-04 - 2s/epoch - 68ms/step
# Epoch 192/200
# 26/26 - 1s - loss: 4.4604e-04 - val_loss: 5.9602e-04 - 1s/epoch - 43ms/step
# Epoch 193/200
# 26/26 - 1s - loss: 4.8676e-04 - val_loss: 6.4715e-04 - 1s/epoch - 43ms/step
# Epoch 194/200
# 26/26 - 1s - loss: 4.5378e-04 - val_loss: 5.0372e-04 - 1s/epoch - 45ms/step
# Epoch 195/200
# 26/26 - 1s - loss: 4.3288e-04 - val_loss: 6.5231e-04 - 1s/epoch - 43ms/step
# Epoch 196/200
# 26/26 - 1s - loss: 4.1567e-04 - val_loss: 5.0495e-04 - 1s/epoch - 43ms/step
# Epoch 197/200
# 26/26 - 1s - loss: 4.4417e-04 - val_loss: 0.0019 - 1s/epoch - 40ms/step
# Epoch 198/200
# 26/26 - 1s - loss: 7.2628e-04 - val_loss: 4.9267e-04 - 1s/epoch - 48ms/step
# Epoch 199/200
# 26/26 - 1s - loss: 4.6542e-04 - val_loss: 4.8873e-04 - 1s/epoch - 41ms/step
# Epoch 200/200
# 26/26 - 2s - loss: 6.4293e-04 - val_loss: 7.6198e-04 - 2s/epoch - 59ms/step

# %% [markdown]
# Dividing Test values into groups

# %% [markdown]
# Prediction

# %%
predicted_price = algo.predict(x_test)
predicted_price = sc.inverse_transform(predicted_price)
# Out:
# 8/8 [==============================] - 0s 7ms/step

# %%
df.reset_index(inplace=True)
plt.plot(df.loc[:t_size+1,'Date'],df.loc[:t_size+1,'Open'], color='green',label="Train data")
plt.plot(df.loc[t_size:, 'Date'],data_test, color = 'red', label = 'Test Data')
plt.plot(df.loc[t_size:, 'Date'],predicted_price, color = 'blue', label = 'Predicted Data')
plt.xticks(np.arange(0,df.shape[0],250))
plt.title('Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel('Stock Price')
plt.legend()
plt.show()

# %%
plt.plot(df.loc[:t_size+1,'Date'],df.loc[:t_size+1,'Open'], color='green',label="Train data")

plt.xticks(np.arange(0,df.shape[0],250))
plt.title('Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel('Stock Price')
plt.legend()
plt.show()

# %%
plt.plot(df.loc[t_size:, 'Date'],data_test, color = 'red', label = 'Test Data')
plt.plot(df.loc[t_size:, 'Date'],predicted_price, color = 'blue', label = 'Predicted Data')
plt.xticks(np.arange(0,x_test.shape[0],50))
plt.title('Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel('Stock Price')
plt.legend()
plt.show()

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error
import numpy as np

mae = mean_absolute_error(data_test,predicted_price)

mse = mean_squared_error(data_test, predicted_price)

rmse = np.sqrt(mse)

print(f'Mean Absolute Error (MAE): {mae:.2f}')
print(f'Mean Squared Error (MSE): {mse:.2f}')
print(f'Root Mean Squared Error (RMSE): {rmse:.2f}')
# Out:
# Mean Absolute Error (MAE): 7.22
# Mean Squared Error (MSE): 76.81
# Root Mean Squared Error (RMSE): 8.76

# %% [markdown]
# Predict Future

# %%
test2=data_test.copy()
for i in range(f_size):
  X=test2[-w_size:]
  X=X.reshape(w_size,1)
  X=sc.fit_transform(X)

  X=np.reshape(X,(1,w_size,1))

  close=algo.predict(X)
  y=sc.inverse_transform(close)

  test2=np.append(test2, y)
# Out:
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 34ms/step

# %%
from datetime import datetime, timedelta
x=df.loc[-1:, 'Date']
day=x[len(x)-1]
date_obj = datetime.strptime(day, '%Y-%m-%d')
start_date = date_obj
date_list = [(start_date + timedelta(days=i)).strftime('%Y-%m-%d') for i in range(f_size)]

# %%
forcasted_data=test2[-f_size:]
plt.plot(date_list,forcasted_data,color='yellow', label="Future data")
plt.xticks(np.arange(0,len(forcasted_data),10))
plt.show()

# %%
plt.plot(df.loc[:t_size,'Date'],df.loc[:t_size,'Open'], color='green',label="Train data")
plt.plot(df.loc[t_size:, 'Date'],data_test, color = 'red', label = 'Test Data')
plt.plot(df.loc[t_size:, 'Date'],predicted_price, color = 'blue', label = 'Predicted Data')
plt.plot(date_list,forcasted_data,color='yellow', label="Future data")
plt.xticks(np.arange(0,df.shape[0],250))
plt.title('Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel('Stock Price')
plt.legend()
plt.show()

# %%
plt.plot(df.loc[t_size:, 'Date'],data_test, color = 'red', label = 'Test Data')
plt.plot(df.loc[t_size:, 'Date'],predicted_price, color = 'blue', label = 'Predicted Data')
plt.plot(date_list,forcasted_data,color='yellow', label="Future data")
plt.xticks(np.arange(0,x_test.shape[0],50))
plt.title('Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel('Stock Price')
plt.legend()
plt.show()
