# %% [markdown]
# <a href="https://colab.research.google.com/github/Ashkabsha/TimeSeries/blob/main/lstm_PRO_29.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Importing Packages

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout
import yfinance as yf
from keras.initializers import RandomNormal

# %%
stock_symbol = 'TSLA'
df = yf.download(stock_symbol,period="60mo",interval="1d")
print(df.head())
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                  Open       High        Low      Close  Adj Close     Volume
# Date
# 2018-11-29  23.133333  23.166668  22.636667  22.744667  22.744667   46210500
# 2018-11-30  22.788668  23.440001  22.550667  23.365334  23.365334   84436500
# 2018-12-03  24.000000  24.400000  23.466667  23.899332  23.899332  124597500
# 2018-12-04  23.736668  24.578667  23.466667  23.980000  23.980000  126928500
# 2018-12-06  23.733999  24.492001  23.384001  24.204000  24.204000  117637500

# %% [markdown]
# Importing Data

# %%
df.index = df.index.strftime('%Y-%m-%d')

# %%
df
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2018-11-29   23.133333   23.166668   22.636667   22.744667   22.744667
# 2018-11-30   22.788668   23.440001   22.550667   23.365334   23.365334
# 2018-12-03   24.000000   24.400000   23.466667   23.899332   23.899332
# 2018-12-04   23.736668   24.578667   23.466667   23.980000   23.980000
# 2018-12-06   23.733999   24.492001   23.384001   24.204000   24.204000
# ...                ...         ...         ...         ...         ...
# 2023-11-22  242.039993  244.009995  231.399994  234.210007  234.210007
# 2023-11-24  233.750000  238.750000  232.330002  235.449997  235.449997
# 2023-11-27  236.889999  238.330002  232.100006  236.080002  236.080002
# 2023-11-28  236.679993  247.000000  234.009995  246.720001  246.720001
# 2023-11-29  249.210007  252.750000  247.720001  250.148895  250.148895
#
#                Volume
# Date
# 2018-11-29   46210500
# 2018-11-30   84436500
# 2018-12-03  124597500
# 2018-12-04  126928500
# 2018-12-06  117637500
# ...               ...
# 2023-11-22  117950600
# 2023-11-24   65125200
# 2023-11-27  112031800
# 2023-11-28  147829500
# 2023-11-29   35826823
#
# [1258 rows x 6 columns]

# %%
len(df)
# Out:
# 1258

# %%
plt.plot(df['Open'],label="Open Price")

plt.xticks(np.arange(0,df.shape[0],250))
plt.title('Stock Data')
plt.xlabel('Date')
plt.ylabel('Open Price')
plt.legend()
plt.show()

# %%
b_size = 32 # Batch Size
epoch = 200 # Number of epochs
train_per = 0.8 # 80% of data taken for training
w_size = 30 # Data for consecutive 30 days are used to predict the next day's data
f_size = 10 #open price for 10 future days

# %%
t_size=int(len(df)*train_per)

# %% [markdown]
# Train-Test Split

# %% [markdown]
# Normalization

# %%
sc = MinMaxScaler(feature_range = (0, 1))

# %% [markdown]
# Create target values

# %%
data_train = df.iloc[:t_size, 1:2].values
data_test = df.iloc[t_size:, 1:2].values
data_total = df.iloc[:,1:2]#open price
sc = MinMaxScaler(feature_range = (0, 1))
training_scaled = sc.fit_transform(data_train)

#Train Data
x_train = []
y_train = []
for iter in range(w_size, t_size):
    x_train.append(training_scaled[iter-w_size:iter, 0])
    y_train.append(training_scaled[iter, 0])
x_train, y_train=np.array(x_train), np.array(y_train)
x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))


#Test data
total_input = data_total[len(data_total) - len(data_test) - w_size:].values
total_input = total_input.reshape(-1, 1)
total_input = sc.transform(total_input)
x_test = []
y_test=[]

# Calculate the maximum number of blocks of length w_size that can be created
blocks = len(total_input) - w_size

for iter in range(blocks):
    x_test.append(total_input[iter:iter+w_size, 0])
    y_test.append(total_input[iter+w_size, 0])     #new addition

x_test = np.array(x_test)
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1))

# %%
df.reset_index(inplace=True)
plt.plot(df.loc[:t_size+1,'Date'],df.loc[:t_size+1,'Open'], color='green',label="Train data")
plt.plot(df.loc[t_size:, 'Date'],data_test, color = 'red', label = 'Test Data')
plt.xticks(np.arange(0,df.shape[0],250))
plt.title('Train Test Split')
plt.xlabel('Date')
plt.ylabel('Open Price')
plt.legend()
plt.show()

# %% [markdown]
# Defining Model

# %%
initializer = RandomNormal(mean = 0.0, stddev = 0.05,seed =5 )
algo = Sequential()
algo.add(LSTM(units = 60, return_sequences = True, input_shape = (x_train.shape[1], 1),kernel_initializer=initializer))
algo.add(Dropout(0.2))
algo.add(LSTM(units = 60))

algo.add(Dense(units = 1))
algo.compile(optimizer = 'adam', loss = 'mean_squared_error')
print(algo.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 30, 60)            14880
#
#  dropout (Dropout)           (None, 30, 60)            0
#
#  lstm_1 (LSTM)               (None, 60)                29040
#
#  dense (Dense)               (None, 1)                 61
#
# =================================================================
# Total params: 43981 (171.80 KB)
# Trainable params: 43981 (171.80 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None

# %% [markdown]
# Training Model

# %%
algo.fit(x_train, y_train, epochs = epoch, batch_size = b_size, validation_split=0.15,verbose=2)
# Out:
# Epoch 1/200
# 26/26 - 17s - loss: 0.0460 - val_loss: 0.0119 - 17s/epoch - 637ms/step
# Epoch 2/200
# 26/26 - 0s - loss: 0.0032 - val_loss: 0.0044 - 198ms/epoch - 8ms/step
# Epoch 3/200
# 26/26 - 0s - loss: 0.0027 - val_loss: 0.0036 - 187ms/epoch - 7ms/step
# Epoch 4/200
# 26/26 - 0s - loss: 0.0024 - val_loss: 0.0049 - 189ms/epoch - 7ms/step
# Epoch 5/200
# 26/26 - 0s - loss: 0.0022 - val_loss: 0.0042 - 185ms/epoch - 7ms/step
# Epoch 6/200
# 26/26 - 0s - loss: 0.0020 - val_loss: 0.0066 - 185ms/epoch - 7ms/step
# Epoch 7/200
# 26/26 - 0s - loss: 0.0024 - val_loss: 0.0052 - 182ms/epoch - 7ms/step
# Epoch 8/200
# 26/26 - 0s - loss: 0.0021 - val_loss: 0.0066 - 181ms/epoch - 7ms/step
# Epoch 9/200
# 26/26 - 0s - loss: 0.0022 - val_loss: 0.0067 - 185ms/epoch - 7ms/step
# Epoch 10/200
# 26/26 - 0s - loss: 0.0020 - val_loss: 0.0053 - 248ms/epoch - 10ms/step
# Epoch 11/200
# 26/26 - 0s - loss: 0.0021 - val_loss: 0.0037 - 255ms/epoch - 10ms/step
# Epoch 12/200
# 26/26 - 0s - loss: 0.0017 - val_loss: 0.0027 - 244ms/epoch - 9ms/step
# Epoch 13/200
# 26/26 - 0s - loss: 0.0015 - val_loss: 0.0023 - 292ms/epoch - 11ms/step
# Epoch 14/200
# 26/26 - 0s - loss: 0.0016 - val_loss: 0.0019 - 241ms/epoch - 9ms/step
# Epoch 15/200
# 26/26 - 0s - loss: 0.0015 - val_loss: 0.0019 - 237ms/epoch - 9ms/step
# Epoch 16/200
# 26/26 - 0s - loss: 0.0015 - val_loss: 0.0023 - 268ms/epoch - 10ms/step
# Epoch 17/200
# 26/26 - 0s - loss: 0.0014 - val_loss: 0.0024 - 257ms/epoch - 10ms/step
# Epoch 18/200
# 26/26 - 0s - loss: 0.0014 - val_loss: 0.0027 - 269ms/epoch - 10ms/step
# Epoch 19/200
# 26/26 - 0s - loss: 0.0014 - val_loss: 0.0019 - 245ms/epoch - 9ms/step
# Epoch 20/200
# 26/26 - 0s - loss: 0.0014 - val_loss: 0.0020 - 263ms/epoch - 10ms/step
# Epoch 21/200
# 26/26 - 0s - loss: 0.0017 - val_loss: 0.0019 - 303ms/epoch - 12ms/step
# Epoch 22/200
# 26/26 - 0s - loss: 0.0012 - val_loss: 0.0020 - 252ms/epoch - 10ms/step
# Epoch 23/200
# 26/26 - 0s - loss: 0.0011 - val_loss: 0.0017 - 209ms/epoch - 8ms/step
# Epoch 24/200
# 26/26 - 0s - loss: 0.0013 - val_loss: 0.0027 - 190ms/epoch - 7ms/step
# Epoch 25/200
# 26/26 - 0s - loss: 0.0013 - val_loss: 0.0015 - 197ms/epoch - 8ms/step
# Epoch 26/200
# 26/26 - 0s - loss: 0.0011 - val_loss: 0.0015 - 190ms/epoch - 7ms/step
# Epoch 27/200
# 26/26 - 0s - loss: 0.0010 - val_loss: 0.0013 - 184ms/epoch - 7ms/step
# Epoch 28/200
# 26/26 - 0s - loss: 0.0012 - val_loss: 0.0015 - 190ms/epoch - 7ms/step
# Epoch 29/200
# 26/26 - 0s - loss: 0.0010 - val_loss: 0.0014 - 188ms/epoch - 7ms/step
# Epoch 30/200
# 26/26 - 0s - loss: 0.0011 - val_loss: 0.0024 - 192ms/epoch - 7ms/step
# Epoch 31/200
# 26/26 - 0s - loss: 0.0011 - val_loss: 0.0012 - 194ms/epoch - 7ms/step
# Epoch 32/200
# 26/26 - 0s - loss: 0.0010 - val_loss: 0.0014 - 182ms/epoch - 7ms/step
# Epoch 33/200
# 26/26 - 0s - loss: 0.0010 - val_loss: 0.0016 - 196ms/epoch - 8ms/step
# Epoch 34/200
# 26/26 - 0s - loss: 9.5125e-04 - val_loss: 0.0015 - 191ms/epoch - 7ms/step
# Epoch 35/200
# 26/26 - 0s - loss: 0.0010 - val_loss: 0.0013 - 198ms/epoch - 8ms/step
# Epoch 36/200
# 26/26 - 0s - loss: 0.0012 - val_loss: 0.0031 - 192ms/epoch - 7ms/step
# Epoch 37/200
# 26/26 - 0s - loss: 0.0011 - val_loss: 0.0012 - 193ms/epoch - 7ms/step
# Epoch 38/200
# 26/26 - 0s - loss: 9.5793e-04 - val_loss: 0.0012 - 193ms/epoch - 7ms/step
# Epoch 39/200
# 26/26 - 0s - loss: 8.1537e-04 - val_loss: 0.0012 - 197ms/epoch - 8ms/step
# Epoch 40/200
# 26/26 - 0s - loss: 9.1055e-04 - val_loss: 0.0023 - 189ms/epoch - 7ms/step
# Epoch 41/200
# 26/26 - 0s - loss: 8.7153e-04 - val_loss: 0.0011 - 191ms/epoch - 7ms/step
# Epoch 42/200
# 26/26 - 0s - loss: 9.2222e-04 - val_loss: 0.0011 - 194ms/epoch - 7ms/step
# Epoch 43/200
# 26/26 - 0s - loss: 8.3635e-04 - val_loss: 0.0016 - 188ms/epoch - 7ms/step
# Epoch 44/200
# 26/26 - 0s - loss: 9.1418e-04 - val_loss: 0.0015 - 197ms/epoch - 8ms/step
# Epoch 45/200
# 26/26 - 0s - loss: 7.9880e-04 - val_loss: 0.0011 - 187ms/epoch - 7ms/step
# Epoch 46/200
# 26/26 - 0s - loss: 8.7167e-04 - val_loss: 0.0022 - 183ms/epoch - 7ms/step
# Epoch 47/200
# 26/26 - 0s - loss: 9.0840e-04 - val_loss: 0.0011 - 188ms/epoch - 7ms/step
# Epoch 48/200
# 26/26 - 0s - loss: 9.5023e-04 - val_loss: 0.0015 - 190ms/epoch - 7ms/step
# Epoch 49/200
# 26/26 - 0s - loss: 7.7466e-04 - val_loss: 0.0012 - 202ms/epoch - 8ms/step
# Epoch 50/200
# 26/26 - 0s - loss: 7.6448e-04 - val_loss: 0.0014 - 192ms/epoch - 7ms/step
# Epoch 51/200
# 26/26 - 0s - loss: 7.5784e-04 - val_loss: 0.0014 - 192ms/epoch - 7ms/step
# Epoch 52/200
# 26/26 - 0s - loss: 8.7778e-04 - val_loss: 0.0020 - 185ms/epoch - 7ms/step
# Epoch 53/200
# 26/26 - 0s - loss: 9.0965e-04 - val_loss: 0.0013 - 186ms/epoch - 7ms/step
# Epoch 54/200
# 26/26 - 0s - loss: 6.9282e-04 - val_loss: 0.0012 - 194ms/epoch - 7ms/step
# Epoch 55/200
# 26/26 - 0s - loss: 8.1346e-04 - val_loss: 0.0018 - 202ms/epoch - 8ms/step
# Epoch 56/200
# 26/26 - 0s - loss: 8.0260e-04 - val_loss: 0.0010 - 204ms/epoch - 8ms/step
# Epoch 57/200
# 26/26 - 0s - loss: 6.8754e-04 - val_loss: 0.0013 - 198ms/epoch - 8ms/step
# Epoch 58/200
# 26/26 - 0s - loss: 7.1319e-04 - val_loss: 0.0010 - 191ms/epoch - 7ms/step
# Epoch 59/200
# 26/26 - 0s - loss: 7.6913e-04 - val_loss: 0.0011 - 199ms/epoch - 8ms/step
# Epoch 60/200
# 26/26 - 0s - loss: 7.7797e-04 - val_loss: 0.0018 - 189ms/epoch - 7ms/step
# Epoch 61/200
# 26/26 - 0s - loss: 7.9670e-04 - val_loss: 0.0010 - 193ms/epoch - 7ms/step
# Epoch 62/200
# 26/26 - 0s - loss: 6.8433e-04 - val_loss: 0.0014 - 187ms/epoch - 7ms/step
# Epoch 63/200
# 26/26 - 0s - loss: 8.4322e-04 - val_loss: 0.0011 - 191ms/epoch - 7ms/step
# Epoch 64/200
# 26/26 - 0s - loss: 7.5161e-04 - val_loss: 0.0012 - 194ms/epoch - 7ms/step
# Epoch 65/200
# 26/26 - 0s - loss: 6.5374e-04 - val_loss: 9.8722e-04 - 192ms/epoch - 7ms/step
# Epoch 66/200
# 26/26 - 0s - loss: 7.0483e-04 - val_loss: 0.0011 - 202ms/epoch - 8ms/step
# Epoch 67/200
# 26/26 - 0s - loss: 6.5357e-04 - val_loss: 0.0012 - 192ms/epoch - 7ms/step
# Epoch 68/200
# 26/26 - 0s - loss: 7.1251e-04 - val_loss: 0.0013 - 203ms/epoch - 8ms/step
# Epoch 69/200
# 26/26 - 0s - loss: 6.9957e-04 - val_loss: 0.0010 - 198ms/epoch - 8ms/step
# Epoch 70/200
# 26/26 - 0s - loss: 7.9529e-04 - val_loss: 0.0013 - 196ms/epoch - 8ms/step
# Epoch 71/200
# 26/26 - 0s - loss: 7.4516e-04 - val_loss: 0.0015 - 195ms/epoch - 8ms/step
# Epoch 72/200
# 26/26 - 0s - loss: 6.9395e-04 - val_loss: 0.0012 - 185ms/epoch - 7ms/step
# Epoch 73/200
# 26/26 - 0s - loss: 7.1164e-04 - val_loss: 9.2399e-04 - 258ms/epoch - 10ms/step
# Epoch 74/200
# 26/26 - 0s - loss: 6.5525e-04 - val_loss: 0.0012 - 299ms/epoch - 11ms/step
# Epoch 75/200
# 26/26 - 0s - loss: 7.3362e-04 - val_loss: 9.0666e-04 - 304ms/epoch - 12ms/step
# Epoch 76/200
# 26/26 - 0s - loss: 6.4676e-04 - val_loss: 0.0010 - 272ms/epoch - 10ms/step
# Epoch 77/200
# 26/26 - 0s - loss: 6.5325e-04 - val_loss: 8.7637e-04 - 259ms/epoch - 10ms/step
# Epoch 78/200
# 26/26 - 0s - loss: 5.9234e-04 - val_loss: 0.0012 - 264ms/epoch - 10ms/step
# Epoch 79/200
# 26/26 - 0s - loss: 6.2095e-04 - val_loss: 8.8028e-04 - 262ms/epoch - 10ms/step
# Epoch 80/200
# 26/26 - 0s - loss: 8.1145e-04 - val_loss: 0.0014 - 268ms/epoch - 10ms/step
# Epoch 81/200
# 26/26 - 0s - loss: 7.3875e-04 - val_loss: 8.5090e-04 - 304ms/epoch - 12ms/step
# Epoch 82/200
# 26/26 - 0s - loss: 6.4608e-04 - val_loss: 0.0012 - 294ms/epoch - 11ms/step
# Epoch 83/200
# 26/26 - 0s - loss: 5.8887e-04 - val_loss: 9.9583e-04 - 271ms/epoch - 10ms/step
# Epoch 84/200
# 26/26 - 0s - loss: 5.8930e-04 - val_loss: 0.0011 - 269ms/epoch - 10ms/step
# Epoch 85/200
# 26/26 - 0s - loss: 6.3348e-04 - val_loss: 8.0507e-04 - 217ms/epoch - 8ms/step
# Epoch 86/200
# 26/26 - 0s - loss: 6.1693e-04 - val_loss: 0.0018 - 194ms/epoch - 7ms/step
# Epoch 87/200
# 26/26 - 0s - loss: 7.6288e-04 - val_loss: 7.9177e-04 - 192ms/epoch - 7ms/step
# Epoch 88/200
# 26/26 - 0s - loss: 5.7696e-04 - val_loss: 7.8848e-04 - 191ms/epoch - 7ms/step
# Epoch 89/200
# 26/26 - 0s - loss: 6.0745e-04 - val_loss: 9.7060e-04 - 186ms/epoch - 7ms/step
# Epoch 90/200
# 26/26 - 0s - loss: 6.2515e-04 - val_loss: 8.5057e-04 - 194ms/epoch - 7ms/step
# Epoch 91/200
# 26/26 - 0s - loss: 5.7407e-04 - val_loss: 7.6164e-04 - 192ms/epoch - 7ms/step
# Epoch 92/200
# 26/26 - 0s - loss: 6.4966e-04 - val_loss: 7.5910e-04 - 193ms/epoch - 7ms/step
# Epoch 93/200
# 26/26 - 0s - loss: 6.1462e-04 - val_loss: 9.9476e-04 - 184ms/epoch - 7ms/step
# Epoch 94/200
# 26/26 - 0s - loss: 5.6069e-04 - val_loss: 0.0018 - 191ms/epoch - 7ms/step
# Epoch 95/200
# 26/26 - 0s - loss: 5.6419e-04 - val_loss: 0.0010 - 186ms/epoch - 7ms/step
# Epoch 96/200
# 26/26 - 0s - loss: 5.4673e-04 - val_loss: 0.0020 - 205ms/epoch - 8ms/step
# Epoch 97/200
# 26/26 - 0s - loss: 5.6035e-04 - val_loss: 0.0010 - 183ms/epoch - 7ms/step
# Epoch 98/200
# 26/26 - 0s - loss: 5.8450e-04 - val_loss: 8.6186e-04 - 186ms/epoch - 7ms/step
# Epoch 99/200
# 26/26 - 0s - loss: 5.8828e-04 - val_loss: 7.8758e-04 - 190ms/epoch - 7ms/step
# Epoch 100/200
# 26/26 - 0s - loss: 5.6177e-04 - val_loss: 7.3016e-04 - 190ms/epoch - 7ms/step
# Epoch 101/200
# 26/26 - 0s - loss: 5.9500e-04 - val_loss: 8.8369e-04 - 212ms/epoch - 8ms/step
# Epoch 102/200
# 26/26 - 0s - loss: 6.1607e-04 - val_loss: 7.6911e-04 - 183ms/epoch - 7ms/step
# Epoch 103/200
# 26/26 - 0s - loss: 6.5251e-04 - val_loss: 8.0177e-04 - 189ms/epoch - 7ms/step
# Epoch 104/200
# 26/26 - 0s - loss: 6.1883e-04 - val_loss: 6.7321e-04 - 197ms/epoch - 8ms/step
# Epoch 105/200
# 26/26 - 0s - loss: 5.1878e-04 - val_loss: 9.5922e-04 - 187ms/epoch - 7ms/step
# Epoch 106/200
# 26/26 - 0s - loss: 5.8021e-04 - val_loss: 7.2187e-04 - 199ms/epoch - 8ms/step
# Epoch 107/200
# 26/26 - 0s - loss: 5.2197e-04 - val_loss: 6.7540e-04 - 193ms/epoch - 7ms/step
# Epoch 108/200
# 26/26 - 0s - loss: 5.1333e-04 - val_loss: 6.4334e-04 - 186ms/epoch - 7ms/step
# Epoch 109/200
# 26/26 - 0s - loss: 5.3787e-04 - val_loss: 7.0846e-04 - 181ms/epoch - 7ms/step
# Epoch 110/200
# 26/26 - 0s - loss: 5.7586e-04 - val_loss: 6.7686e-04 - 191ms/epoch - 7ms/step
# Epoch 111/200
# 26/26 - 0s - loss: 4.9956e-04 - val_loss: 0.0011 - 202ms/epoch - 8ms/step
# Epoch 112/200
# 26/26 - 0s - loss: 6.7823e-04 - val_loss: 6.3134e-04 - 186ms/epoch - 7ms/step
# Epoch 113/200
# 26/26 - 0s - loss: 7.7558e-04 - val_loss: 7.4545e-04 - 196ms/epoch - 8ms/step
# Epoch 114/200
# 26/26 - 0s - loss: 5.1887e-04 - val_loss: 6.8034e-04 - 195ms/epoch - 8ms/step
# Epoch 115/200
# 26/26 - 0s - loss: 6.0243e-04 - val_loss: 6.3297e-04 - 198ms/epoch - 8ms/step
# Epoch 116/200
# 26/26 - 0s - loss: 4.7416e-04 - val_loss: 5.9933e-04 - 199ms/epoch - 8ms/step
# Epoch 117/200
# 26/26 - 0s - loss: 5.3633e-04 - val_loss: 8.1428e-04 - 211ms/epoch - 8ms/step
# Epoch 118/200
# 26/26 - 0s - loss: 4.9550e-04 - val_loss: 5.8481e-04 - 193ms/epoch - 7ms/step
# Epoch 119/200
# 26/26 - 0s - loss: 5.2390e-04 - val_loss: 0.0016 - 184ms/epoch - 7ms/step
# Epoch 120/200
# 26/26 - 0s - loss: 5.8811e-04 - val_loss: 0.0015 - 187ms/epoch - 7ms/step
# Epoch 121/200
# 26/26 - 0s - loss: 6.0257e-04 - val_loss: 0.0011 - 191ms/epoch - 7ms/step
# Epoch 122/200
# 26/26 - 0s - loss: 5.3229e-04 - val_loss: 9.6522e-04 - 182ms/epoch - 7ms/step
# Epoch 123/200
# 26/26 - 0s - loss: 6.2865e-04 - val_loss: 5.7105e-04 - 185ms/epoch - 7ms/step
# Epoch 124/200
# 26/26 - 0s - loss: 5.4835e-04 - val_loss: 5.6029e-04 - 188ms/epoch - 7ms/step
# Epoch 125/200
# 26/26 - 0s - loss: 5.2726e-04 - val_loss: 5.9909e-04 - 193ms/epoch - 7ms/step
# Epoch 126/200
# 26/26 - 0s - loss: 4.6896e-04 - val_loss: 5.4228e-04 - 189ms/epoch - 7ms/step
# Epoch 127/200
# 26/26 - 0s - loss: 4.6002e-04 - val_loss: 5.7661e-04 - 191ms/epoch - 7ms/step
# Epoch 128/200
# 26/26 - 0s - loss: 4.3619e-04 - val_loss: 8.9185e-04 - 189ms/epoch - 7ms/step
# Epoch 129/200
# 26/26 - 0s - loss: 4.5412e-04 - val_loss: 5.4135e-04 - 182ms/epoch - 7ms/step
# Epoch 130/200
# 26/26 - 0s - loss: 4.7467e-04 - val_loss: 9.4831e-04 - 194ms/epoch - 7ms/step
# Epoch 131/200
# 26/26 - 0s - loss: 5.1814e-04 - val_loss: 8.7192e-04 - 194ms/epoch - 7ms/step
# Epoch 132/200
# 26/26 - 0s - loss: 4.3295e-04 - val_loss: 5.1998e-04 - 199ms/epoch - 8ms/step
# Epoch 133/200
# 26/26 - 0s - loss: 4.3255e-04 - val_loss: 5.1740e-04 - 186ms/epoch - 7ms/step
# Epoch 134/200
# 26/26 - 0s - loss: 4.3194e-04 - val_loss: 5.1514e-04 - 187ms/epoch - 7ms/step
# Epoch 135/200
# 26/26 - 0s - loss: 4.5732e-04 - val_loss: 5.4712e-04 - 190ms/epoch - 7ms/step
# Epoch 136/200
# 26/26 - 0s - loss: 4.4522e-04 - val_loss: 5.0671e-04 - 276ms/epoch - 11ms/step
# Epoch 137/200
# 26/26 - 0s - loss: 4.8326e-04 - val_loss: 7.1507e-04 - 298ms/epoch - 11ms/step
# Epoch 138/200
# 26/26 - 0s - loss: 4.7104e-04 - val_loss: 6.3195e-04 - 266ms/epoch - 10ms/step
# Epoch 139/200
# 26/26 - 0s - loss: 5.6864e-04 - val_loss: 5.4047e-04 - 248ms/epoch - 10ms/step
# Epoch 140/200
# 26/26 - 0s - loss: 4.9852e-04 - val_loss: 0.0012 - 250ms/epoch - 10ms/step
# Epoch 141/200
# 26/26 - 0s - loss: 4.5027e-04 - val_loss: 6.6185e-04 - 247ms/epoch - 9ms/step
# Epoch 142/200
# 26/26 - 0s - loss: 4.1885e-04 - val_loss: 5.0731e-04 - 294ms/epoch - 11ms/step
# Epoch 143/200
# 26/26 - 0s - loss: 3.8785e-04 - val_loss: 5.7444e-04 - 257ms/epoch - 10ms/step
# Epoch 144/200
# 26/26 - 0s - loss: 4.7309e-04 - val_loss: 6.8051e-04 - 272ms/epoch - 10ms/step
# Epoch 145/200
# 26/26 - 0s - loss: 4.0999e-04 - val_loss: 5.1615e-04 - 257ms/epoch - 10ms/step
# Epoch 146/200
# 26/26 - 0s - loss: 4.4989e-04 - val_loss: 5.1473e-04 - 294ms/epoch - 11ms/step
# Epoch 147/200
# 26/26 - 0s - loss: 5.3125e-04 - val_loss: 0.0010 - 296ms/epoch - 11ms/step
# Epoch 148/200
# 26/26 - 0s - loss: 4.7588e-04 - val_loss: 5.3954e-04 - 224ms/epoch - 9ms/step
# Epoch 149/200
# 26/26 - 0s - loss: 4.7968e-04 - val_loss: 5.8731e-04 - 186ms/epoch - 7ms/step
# Epoch 150/200
# 26/26 - 0s - loss: 4.4753e-04 - val_loss: 4.9720e-04 - 189ms/epoch - 7ms/step
# Epoch 151/200
# 26/26 - 0s - loss: 4.7335e-04 - val_loss: 4.6975e-04 - 192ms/epoch - 7ms/step
# Epoch 152/200
# 26/26 - 0s - loss: 4.1227e-04 - val_loss: 4.8669e-04 - 202ms/epoch - 8ms/step
# Epoch 153/200
# 26/26 - 0s - loss: 4.3344e-04 - val_loss: 4.6901e-04 - 207ms/epoch - 8ms/step
# Epoch 154/200
# 26/26 - 0s - loss: 4.7117e-04 - val_loss: 5.7788e-04 - 194ms/epoch - 7ms/step
# Epoch 155/200
# 26/26 - 0s - loss: 5.6083e-04 - val_loss: 8.6054e-04 - 198ms/epoch - 8ms/step
# Epoch 156/200
# 26/26 - 0s - loss: 4.8331e-04 - val_loss: 4.6534e-04 - 197ms/epoch - 8ms/step
# Epoch 157/200
# 26/26 - 0s - loss: 5.1262e-04 - val_loss: 6.7893e-04 - 194ms/epoch - 7ms/step
# Epoch 158/200
# 26/26 - 0s - loss: 4.6083e-04 - val_loss: 4.6710e-04 - 191ms/epoch - 7ms/step
# Epoch 159/200
# 26/26 - 0s - loss: 4.7187e-04 - val_loss: 4.7520e-04 - 188ms/epoch - 7ms/step
# Epoch 160/200
# 26/26 - 0s - loss: 4.2859e-04 - val_loss: 5.3710e-04 - 181ms/epoch - 7ms/step
# Epoch 161/200
# 26/26 - 0s - loss: 4.2173e-04 - val_loss: 9.5345e-04 - 188ms/epoch - 7ms/step
# Epoch 162/200
# 26/26 - 0s - loss: 5.2076e-04 - val_loss: 4.6736e-04 - 189ms/epoch - 7ms/step
# Epoch 163/200
# 26/26 - 0s - loss: 4.9215e-04 - val_loss: 0.0010 - 189ms/epoch - 7ms/step
# Epoch 164/200
# 26/26 - 0s - loss: 5.2837e-04 - val_loss: 5.4441e-04 - 202ms/epoch - 8ms/step
# Epoch 165/200
# 26/26 - 0s - loss: 4.4488e-04 - val_loss: 4.9740e-04 - 193ms/epoch - 7ms/step
# Epoch 166/200
# 26/26 - 0s - loss: 4.7073e-04 - val_loss: 5.9224e-04 - 181ms/epoch - 7ms/step
# Epoch 167/200
# 26/26 - 0s - loss: 4.5051e-04 - val_loss: 5.7538e-04 - 187ms/epoch - 7ms/step
# Epoch 168/200
# 26/26 - 0s - loss: 4.8221e-04 - val_loss: 5.9552e-04 - 188ms/epoch - 7ms/step
# Epoch 169/200
# 26/26 - 0s - loss: 5.1521e-04 - val_loss: 4.5516e-04 - 193ms/epoch - 7ms/step
# Epoch 170/200
# 26/26 - 0s - loss: 4.3500e-04 - val_loss: 6.7120e-04 - 185ms/epoch - 7ms/step
# Epoch 171/200
# 26/26 - 0s - loss: 4.5443e-04 - val_loss: 6.3815e-04 - 194ms/epoch - 7ms/step
# Epoch 172/200
# 26/26 - 0s - loss: 4.5099e-04 - val_loss: 4.8259e-04 - 181ms/epoch - 7ms/step
# Epoch 173/200
# 26/26 - 0s - loss: 4.2617e-04 - val_loss: 4.5895e-04 - 191ms/epoch - 7ms/step
# Epoch 174/200
# 26/26 - 0s - loss: 4.7124e-04 - val_loss: 8.5862e-04 - 192ms/epoch - 7ms/step
# Epoch 175/200
# 26/26 - 0s - loss: 4.4183e-04 - val_loss: 4.7027e-04 - 185ms/epoch - 7ms/step
# Epoch 176/200
# 26/26 - 0s - loss: 4.7665e-04 - val_loss: 6.1485e-04 - 198ms/epoch - 8ms/step
# Epoch 177/200
# 26/26 - 0s - loss: 3.7036e-04 - val_loss: 6.0029e-04 - 187ms/epoch - 7ms/step
# Epoch 178/200
# 26/26 - 0s - loss: 3.8154e-04 - val_loss: 4.7039e-04 - 193ms/epoch - 7ms/step
# Epoch 179/200
# 26/26 - 0s - loss: 4.0551e-04 - val_loss: 4.8624e-04 - 191ms/epoch - 7ms/step
# Epoch 180/200
# 26/26 - 0s - loss: 4.3236e-04 - val_loss: 6.2884e-04 - 189ms/epoch - 7ms/step
# Epoch 181/200
# 26/26 - 0s - loss: 4.4173e-04 - val_loss: 4.4873e-04 - 191ms/epoch - 7ms/step
# Epoch 182/200
# 26/26 - 0s - loss: 3.9695e-04 - val_loss: 4.7582e-04 - 197ms/epoch - 8ms/step
# Epoch 183/200
# 26/26 - 0s - loss: 3.9371e-04 - val_loss: 7.2670e-04 - 190ms/epoch - 7ms/step
# Epoch 184/200
# 26/26 - 0s - loss: 4.5956e-04 - val_loss: 6.5286e-04 - 201ms/epoch - 8ms/step
# Epoch 185/200
# 26/26 - 0s - loss: 4.2654e-04 - val_loss: 4.5563e-04 - 201ms/epoch - 8ms/step
# Epoch 186/200
# 26/26 - 0s - loss: 3.8082e-04 - val_loss: 5.1023e-04 - 190ms/epoch - 7ms/step
# Epoch 187/200
# 26/26 - 0s - loss: 4.2213e-04 - val_loss: 5.5936e-04 - 188ms/epoch - 7ms/step
# Epoch 188/200
# 26/26 - 0s - loss: 3.5219e-04 - val_loss: 4.9532e-04 - 194ms/epoch - 7ms/step
# Epoch 189/200
# 26/26 - 0s - loss: 4.5768e-04 - val_loss: 4.8826e-04 - 190ms/epoch - 7ms/step
# Epoch 190/200
# 26/26 - 0s - loss: 4.0251e-04 - val_loss: 4.7193e-04 - 198ms/epoch - 8ms/step
# Epoch 191/200
# 26/26 - 0s - loss: 3.8620e-04 - val_loss: 4.6859e-04 - 190ms/epoch - 7ms/step
# Epoch 192/200
# 26/26 - 0s - loss: 3.8651e-04 - val_loss: 4.6938e-04 - 187ms/epoch - 7ms/step
# Epoch 193/200
# 26/26 - 0s - loss: 3.6483e-04 - val_loss: 4.5886e-04 - 191ms/epoch - 7ms/step
# Epoch 194/200
# 26/26 - 0s - loss: 3.6344e-04 - val_loss: 5.5856e-04 - 199ms/epoch - 8ms/step
# Epoch 195/200
# 26/26 - 0s - loss: 4.6316e-04 - val_loss: 4.6631e-04 - 201ms/epoch - 8ms/step
# Epoch 196/200
# 26/26 - 0s - loss: 4.9991e-04 - val_loss: 4.7649e-04 - 206ms/epoch - 8ms/step
# Epoch 197/200
# 26/26 - 0s - loss: 3.9239e-04 - val_loss: 7.9250e-04 - 186ms/epoch - 7ms/step
# Epoch 198/200
# 26/26 - 0s - loss: 4.2808e-04 - val_loss: 4.4540e-04 - 195ms/epoch - 7ms/step
# Epoch 199/200
# 26/26 - 0s - loss: 4.0857e-04 - val_loss: 5.9862e-04 - 280ms/epoch - 11ms/step
# Epoch 200/200
# 26/26 - 0s - loss: 4.5105e-04 - val_loss: 4.8919e-04 - 307ms/epoch - 12ms/step

# %% [markdown]
# Dividing Test values into groups

# %% [markdown]
# Prediction

# %%
predicted_price = algo.predict(x_test)
predicted_price = sc.inverse_transform(predicted_price)
# Out:
# 8/8 [==============================] - 1s 4ms/step

# %%
df.reset_index(inplace=True)
plt.plot(df.loc[:t_size+1,'Date'],df.loc[:t_size+1,'Open'], color='green',label="Train data")
plt.plot(df.loc[t_size:, 'Date'],data_test, color = 'red', label = 'Test Data')
plt.plot(df.loc[t_size:, 'Date'],predicted_price, color = 'blue', label = 'Predicted Data')
plt.xticks(np.arange(0,df.shape[0],250))
plt.title('Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel('Stock Price')
plt.legend()
plt.show()

# %%
plt.plot(df.loc[:t_size+1,'Date'],df.loc[:t_size+1,'Open'], color='green',label="Train data")

plt.xticks(np.arange(0,df.shape[0],250))
plt.title('Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel('Stock Price')
plt.legend()
plt.show()

# %%
plt.plot(df.loc[t_size:, 'Date'],data_test, color = 'red', label = 'Test Data')
plt.plot(df.loc[t_size:, 'Date'],predicted_price, color = 'blue', label = 'Predicted Data')
plt.xticks(np.arange(0,x_test.shape[0],50))
plt.title('Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel('Stock Price')
plt.legend()
plt.show()

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error
import numpy as np

mae = mean_absolute_error(data_test,predicted_price)

mse = mean_squared_error(data_test, predicted_price)

rmse = np.sqrt(mse)

print(f'Mean Absolute Error (MAE): {mae:.2f}')
print(f'Mean Squared Error (MSE): {mse:.2f}')
print(f'Root Mean Squared Error (RMSE): {rmse:.2f}')
# Out:
# Mean Absolute Error (MAE): 5.56
# Mean Squared Error (MSE): 49.87
# Root Mean Squared Error (RMSE): 7.06

# %% [markdown]
# Predict Future

# %%
test2=data_test.copy()
for i in range(f_size):
  X=test2[-w_size:]
  X=X.reshape(w_size,1)
  X=sc.fit_transform(X)

  X=np.reshape(X,(1,w_size,1))

  close=algo.predict(X)
  y=sc.inverse_transform(close)

  test2=np.append(test2, y)
# Out:
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step

# %%
from datetime import datetime, timedelta
x=df.loc[-1:, 'Date']
day=x[len(x)-1]
date_obj = datetime.strptime(day, '%Y-%m-%d')
start_date = date_obj
date_list = [(start_date + timedelta(days=i)).strftime('%Y-%m-%d') for i in range(f_size)]

# %%
forcasted_data=test2[-f_size:]
plt.plot(date_list,forcasted_data,color='yellow', label="Future data")
plt.xticks(np.arange(0,len(forcasted_data),10))
plt.show()

# %%
plt.plot(df.loc[:t_size,'Date'],df.loc[:t_size,'Open'], color='green',label="Train data")
plt.plot(df.loc[t_size:, 'Date'],data_test, color = 'red', label = 'Test Data')
plt.plot(df.loc[t_size:, 'Date'],predicted_price, color = 'blue', label = 'Predicted Data')
plt.plot(date_list,forcasted_data,color='yellow', label="Future data")
plt.xticks(np.arange(0,df.shape[0],250))
plt.title('Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel('Stock Price')
plt.legend()
plt.show()

# %%
plt.plot(df.loc[t_size:, 'Date'],data_test, color = 'red', label = 'Test Data')
plt.plot(df.loc[t_size:, 'Date'],predicted_price, color = 'blue', label = 'Predicted Data')
plt.plot(date_list,forcasted_data,color='yellow', label="Future data")
plt.xticks(np.arange(0,x_test.shape[0],50))
plt.title('Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel('Stock Price')
plt.legend()
plt.show()
