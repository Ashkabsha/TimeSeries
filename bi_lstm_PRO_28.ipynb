# %% [markdown]
# <a href="https://colab.research.google.com/github/Ashkabsha/TimeSeries/blob/main/bi_lstm_PRO_28.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Importing Packages

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout
import yfinance as yf
from keras.initializers import RandomNormal
from keras.layers import Bidirectional

# %%
stock_symbol = 'AAPL'
df = yf.download(stock_symbol,period="60mo",interval="1d")
print(df.head())
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                  Open       High        Low      Close  Adj Close     Volume
# Date
# 2018-11-28  44.182499  45.322498  43.732498  45.235001  43.417042  184250000
# 2018-11-29  45.665001  45.700001  44.424999  44.887501  43.083504  167080000
# 2018-11-30  45.072498  45.082500  44.257500  44.645000  42.850761  158126000
# 2018-12-03  46.115002  46.235001  45.302502  46.205002  44.348068  163210000
# 2018-12-04  45.237499  45.597500  44.067501  44.172501  42.397247  165377200

# %% [markdown]
# Importing Data

# %%
df.index = df.index.strftime('%Y-%m-%d')

# %%
df
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2018-11-28   44.182499   45.322498   43.732498   45.235001   43.417042
# 2018-11-29   45.665001   45.700001   44.424999   44.887501   43.083504
# 2018-11-30   45.072498   45.082500   44.257500   44.645000   42.850761
# 2018-12-03   46.115002   46.235001   45.302502   46.205002   44.348068
# 2018-12-04   45.237499   45.597500   44.067501   44.172501   42.397247
# ...                ...         ...         ...         ...         ...
# 2023-11-20  189.889999  191.910004  189.880005  191.449997  191.449997
# 2023-11-21  191.410004  191.520004  189.740005  190.639999  190.639999
# 2023-11-22  191.490005  192.929993  190.830002  191.309998  191.309998
# 2023-11-24  190.869995  190.899994  189.250000  189.970001  189.970001
# 2023-11-27  189.919998  190.669998  188.899994  189.789993  189.789993
#
#                Volume
# Date
# 2018-11-28  184250000
# 2018-11-29  167080000
# 2018-11-30  158126000
# 2018-12-03  163210000
# 2018-12-04  165377200
# ...               ...
# 2023-11-20   46505100
# 2023-11-21   38134500
# 2023-11-22   39617700
# 2023-11-24   24048300
# 2023-11-27   40500500
#
# [1257 rows x 6 columns]

# %%
len(df)
# Out:
# 1257

# %%
df['Open'].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
b_size=32
epoch=200
train_per=0.8
w_size=30
f_size=10

# %%
t_size=int(len(df)*train_per)

# %% [markdown]
# Normalization

# %%
sc = MinMaxScaler(feature_range = (0, 1))

# %% [markdown]
# Create target values

# %%
data_train = df.iloc[:t_size, 1:2].values
data_test = df.iloc[t_size:, 1:2].values
data_total = df.iloc[:,1:2]#open price
sc = MinMaxScaler(feature_range = (0, 1))
training_scaled = sc.fit_transform(data_train)

#Train Data
x_train = []
y_train = []
for iter in range(w_size, t_size):
    x_train.append(training_scaled[iter-w_size:iter, 0])
    y_train.append(training_scaled[iter, 0])
x_train, y_train=np.array(x_train), np.array(y_train)
x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))


#Test data
total_input = data_total[len(data_total) - len(data_test) - w_size:].values
total_input = total_input.reshape(-1, 1)
total_input = sc.transform(total_input)
x_test = []
y_test=[]

# Calculate the maximum number of blocks of length w_size that can be created
blocks = len(total_input) - w_size

for iter in range(blocks):
    x_test.append(total_input[iter:iter+w_size, 0])
    y_test.append(total_input[iter+w_size, 0])     #new addition

x_test = np.array(x_test)
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1))

# %% [markdown]
# Defining Model

# %%
initializer = RandomNormal(mean=0.0, stddev=0.05)
algo = Sequential()
algo.add(Bidirectional(LSTM(60,return_sequences=True,activation='relu',input_shape = (x_train.shape[1], 1),kernel_initializer=initializer)))
algo.add(Dropout(0.2))
algo.add(Bidirectional(LSTM(60)))
algo.add(Dense(1))
algo.compile(optimizer = 'adam', loss = 'mean_squared_error')
# Out:
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.

# %% [markdown]
# Training Model

# %%
algo.fit(x_train, y_train, epochs = epoch, batch_size = b_size, validation_split=0.15,verbose=2)
# Out:
# Epoch 1/200
# 26/26 - 26s - loss: 0.0553 - val_loss: 0.0047 - 26s/epoch - 981ms/step
# Epoch 2/200
# 26/26 - 2s - loss: 0.0022 - val_loss: 0.0038 - 2s/epoch - 86ms/step
# Epoch 3/200
# 26/26 - 2s - loss: 0.0017 - val_loss: 0.0045 - 2s/epoch - 84ms/step
# Epoch 4/200
# 26/26 - 2s - loss: 0.0015 - val_loss: 0.0044 - 2s/epoch - 88ms/step
# Epoch 5/200
# 26/26 - 3s - loss: 0.0015 - val_loss: 0.0058 - 3s/epoch - 116ms/step
# Epoch 6/200
# 26/26 - 6s - loss: 0.0015 - val_loss: 0.0041 - 6s/epoch - 218ms/step
# Epoch 7/200
# 26/26 - 5s - loss: 0.0013 - val_loss: 0.0035 - 5s/epoch - 201ms/step
# Epoch 8/200
# 26/26 - 5s - loss: 0.0013 - val_loss: 0.0029 - 5s/epoch - 192ms/step
# Epoch 9/200
# 26/26 - 2s - loss: 0.0012 - val_loss: 0.0030 - 2s/epoch - 89ms/step
# Epoch 10/200
# 26/26 - 2s - loss: 0.0011 - val_loss: 0.0034 - 2s/epoch - 84ms/step
# Epoch 11/200
# 26/26 - 2s - loss: 0.0011 - val_loss: 0.0024 - 2s/epoch - 86ms/step
# Epoch 12/200
# 26/26 - 2s - loss: 0.0010 - val_loss: 0.0024 - 2s/epoch - 87ms/step
# Epoch 13/200
# 26/26 - 3s - loss: 0.0011 - val_loss: 0.0022 - 3s/epoch - 129ms/step
# Epoch 14/200
# 26/26 - 3s - loss: 0.0011 - val_loss: 0.0023 - 3s/epoch - 110ms/step
# Epoch 15/200
# 26/26 - 2s - loss: 9.8636e-04 - val_loss: 0.0021 - 2s/epoch - 87ms/step
# Epoch 16/200
# 26/26 - 2s - loss: 0.0010 - val_loss: 0.0017 - 2s/epoch - 86ms/step
# Epoch 17/200
# 26/26 - 2s - loss: 0.0011 - val_loss: 0.0017 - 2s/epoch - 86ms/step
# Epoch 18/200
# 26/26 - 2s - loss: 0.0012 - val_loss: 0.0021 - 2s/epoch - 94ms/step
# Epoch 19/200
# 26/26 - 4s - loss: 9.6713e-04 - val_loss: 0.0017 - 4s/epoch - 143ms/step
# Epoch 20/200
# 26/26 - 2s - loss: 8.5315e-04 - val_loss: 0.0017 - 2s/epoch - 82ms/step
# Epoch 21/200
# 26/26 - 2s - loss: 0.0011 - val_loss: 0.0016 - 2s/epoch - 82ms/step
# Epoch 22/200
# 26/26 - 2s - loss: 8.3871e-04 - val_loss: 0.0016 - 2s/epoch - 86ms/step
# Epoch 23/200
# 26/26 - 2s - loss: 8.5815e-04 - val_loss: 0.0016 - 2s/epoch - 82ms/step
# Epoch 24/200
# 26/26 - 4s - loss: 8.7589e-04 - val_loss: 0.0018 - 4s/epoch - 135ms/step
# Epoch 25/200
# 26/26 - 2s - loss: 9.0114e-04 - val_loss: 0.0015 - 2s/epoch - 96ms/step
# Epoch 26/200
# 26/26 - 2s - loss: 7.4856e-04 - val_loss: 0.0021 - 2s/epoch - 90ms/step
# Epoch 27/200
# 26/26 - 3s - loss: 7.7194e-04 - val_loss: 0.0020 - 3s/epoch - 106ms/step
# Epoch 28/200
# 26/26 - 2s - loss: 7.3562e-04 - val_loss: 0.0015 - 2s/epoch - 84ms/step
# Epoch 29/200
# 26/26 - 3s - loss: 7.0959e-04 - val_loss: 0.0014 - 3s/epoch - 124ms/step
# Epoch 30/200
# 26/26 - 3s - loss: 7.7612e-04 - val_loss: 0.0014 - 3s/epoch - 105ms/step
# Epoch 31/200
# 26/26 - 2s - loss: 6.8185e-04 - val_loss: 0.0013 - 2s/epoch - 88ms/step
# Epoch 32/200
# 26/26 - 2s - loss: 6.7161e-04 - val_loss: 0.0021 - 2s/epoch - 84ms/step
# Epoch 33/200
# 26/26 - 2s - loss: 6.5720e-04 - val_loss: 0.0015 - 2s/epoch - 90ms/step
# Epoch 34/200
# 26/26 - 2s - loss: 8.7392e-04 - val_loss: 0.0022 - 2s/epoch - 93ms/step
# Epoch 35/200
# 26/26 - 4s - loss: 7.1439e-04 - val_loss: 0.0015 - 4s/epoch - 143ms/step
# Epoch 36/200
# 26/26 - 3s - loss: 6.5191e-04 - val_loss: 0.0014 - 3s/epoch - 99ms/step
# Epoch 37/200
# 26/26 - 3s - loss: 7.0458e-04 - val_loss: 0.0013 - 3s/epoch - 101ms/step
# Epoch 38/200
# 26/26 - 2s - loss: 7.6263e-04 - val_loss: 0.0014 - 2s/epoch - 83ms/step
# Epoch 39/200
# 26/26 - 2s - loss: 7.1107e-04 - val_loss: 0.0013 - 2s/epoch - 91ms/step
# Epoch 40/200
# 26/26 - 4s - loss: 6.4785e-04 - val_loss: 0.0013 - 4s/epoch - 144ms/step
# Epoch 41/200
# 26/26 - 2s - loss: 6.2177e-04 - val_loss: 0.0013 - 2s/epoch - 90ms/step
# Epoch 42/200
# 26/26 - 2s - loss: 6.3751e-04 - val_loss: 0.0012 - 2s/epoch - 84ms/step
# Epoch 43/200
# 26/26 - 2s - loss: 6.5288e-04 - val_loss: 0.0020 - 2s/epoch - 88ms/step
# Epoch 44/200
# 26/26 - 2s - loss: 7.5164e-04 - val_loss: 0.0012 - 2s/epoch - 85ms/step
# Epoch 45/200
# 26/26 - 4s - loss: 6.4308e-04 - val_loss: 0.0016 - 4s/epoch - 148ms/step
# Epoch 46/200
# 26/26 - 2s - loss: 6.3688e-04 - val_loss: 0.0012 - 2s/epoch - 85ms/step
# Epoch 47/200
# 26/26 - 2s - loss: 5.7528e-04 - val_loss: 0.0012 - 2s/epoch - 85ms/step
# Epoch 48/200
# 26/26 - 2s - loss: 6.3754e-04 - val_loss: 0.0016 - 2s/epoch - 85ms/step
# Epoch 49/200
# 26/26 - 2s - loss: 5.9563e-04 - val_loss: 0.0011 - 2s/epoch - 86ms/step
# Epoch 50/200
# 26/26 - 3s - loss: 5.9358e-04 - val_loss: 0.0016 - 3s/epoch - 130ms/step
# Epoch 51/200
# 26/26 - 3s - loss: 6.3022e-04 - val_loss: 0.0012 - 3s/epoch - 103ms/step
# Epoch 52/200
# 26/26 - 2s - loss: 5.6662e-04 - val_loss: 0.0011 - 2s/epoch - 87ms/step
# Epoch 53/200
# 26/26 - 2s - loss: 6.7430e-04 - val_loss: 0.0011 - 2s/epoch - 86ms/step
# Epoch 54/200
# 26/26 - 2s - loss: 6.4343e-04 - val_loss: 0.0011 - 2s/epoch - 83ms/step
# Epoch 55/200
# 26/26 - 2s - loss: 6.1736e-04 - val_loss: 0.0015 - 2s/epoch - 94ms/step
# Epoch 56/200
# 26/26 - 4s - loss: 6.1230e-04 - val_loss: 0.0019 - 4s/epoch - 140ms/step
# Epoch 57/200
# 26/26 - 2s - loss: 6.4656e-04 - val_loss: 0.0011 - 2s/epoch - 84ms/step
# Epoch 58/200
# 26/26 - 2s - loss: 6.5848e-04 - val_loss: 0.0012 - 2s/epoch - 85ms/step
# Epoch 59/200
# 26/26 - 2s - loss: 5.9796e-04 - val_loss: 0.0011 - 2s/epoch - 80ms/step
# Epoch 60/200
# 26/26 - 2s - loss: 5.6954e-04 - val_loss: 0.0010 - 2s/epoch - 85ms/step
# Epoch 61/200
# 26/26 - 4s - loss: 5.4744e-04 - val_loss: 0.0010 - 4s/epoch - 135ms/step
# Epoch 62/200
# 26/26 - 2s - loss: 5.0707e-04 - val_loss: 0.0020 - 2s/epoch - 93ms/step
# Epoch 63/200
# 26/26 - 2s - loss: 6.9064e-04 - val_loss: 0.0010 - 2s/epoch - 94ms/step
# Epoch 64/200
# 26/26 - 2s - loss: 5.6886e-04 - val_loss: 0.0010 - 2s/epoch - 82ms/step
# Epoch 65/200
# 26/26 - 2s - loss: 6.3437e-04 - val_loss: 0.0015 - 2s/epoch - 87ms/step
# Epoch 66/200
# 26/26 - 2s - loss: 4.8652e-04 - val_loss: 0.0010 - 2s/epoch - 96ms/step
# Epoch 67/200
# 26/26 - 3s - loss: 5.2333e-04 - val_loss: 0.0016 - 3s/epoch - 132ms/step
# Epoch 68/200
# 26/26 - 2s - loss: 6.2531e-04 - val_loss: 9.2318e-04 - 2s/epoch - 86ms/step
# Epoch 69/200
# 26/26 - 2s - loss: 4.8745e-04 - val_loss: 9.4446e-04 - 2s/epoch - 84ms/step
# Epoch 70/200
# 26/26 - 2s - loss: 5.2658e-04 - val_loss: 0.0011 - 2s/epoch - 81ms/step
# Epoch 71/200
# 26/26 - 2s - loss: 5.7708e-04 - val_loss: 0.0013 - 2s/epoch - 83ms/step
# Epoch 72/200
# 26/26 - 4s - loss: 5.7978e-04 - val_loss: 9.9081e-04 - 4s/epoch - 146ms/step
# Epoch 73/200
# 26/26 - 2s - loss: 5.4732e-04 - val_loss: 0.0011 - 2s/epoch - 84ms/step
# Epoch 74/200
# 26/26 - 2s - loss: 5.3010e-04 - val_loss: 0.0011 - 2s/epoch - 86ms/step
# Epoch 75/200
# 26/26 - 2s - loss: 4.4658e-04 - val_loss: 0.0012 - 2s/epoch - 88ms/step
# Epoch 76/200
# 26/26 - 2s - loss: 4.8127e-04 - val_loss: 0.0012 - 2s/epoch - 85ms/step
# Epoch 77/200
# 26/26 - 3s - loss: 4.5931e-04 - val_loss: 8.4815e-04 - 3s/epoch - 106ms/step
# Epoch 78/200
# 26/26 - 3s - loss: 5.1263e-04 - val_loss: 0.0013 - 3s/epoch - 124ms/step
# Epoch 79/200
# 26/26 - 2s - loss: 5.8877e-04 - val_loss: 9.5876e-04 - 2s/epoch - 87ms/step
# Epoch 80/200
# 26/26 - 2s - loss: 5.7495e-04 - val_loss: 0.0016 - 2s/epoch - 87ms/step
# Epoch 81/200
# 26/26 - 2s - loss: 4.9722e-04 - val_loss: 8.6192e-04 - 2s/epoch - 83ms/step
# Epoch 82/200
# 26/26 - 2s - loss: 5.9469e-04 - val_loss: 0.0012 - 2s/epoch - 84ms/step
# Epoch 83/200
# 26/26 - 4s - loss: 7.1179e-04 - val_loss: 9.2827e-04 - 4s/epoch - 148ms/step
# Epoch 84/200
# 26/26 - 2s - loss: 5.8148e-04 - val_loss: 8.8240e-04 - 2s/epoch - 85ms/step
# Epoch 85/200
# 26/26 - 2s - loss: 4.9282e-04 - val_loss: 0.0014 - 2s/epoch - 80ms/step
# Epoch 86/200
# 26/26 - 2s - loss: 5.6688e-04 - val_loss: 0.0012 - 2s/epoch - 88ms/step
# Epoch 87/200
# 26/26 - 2s - loss: 4.7290e-04 - val_loss: 0.0012 - 2s/epoch - 87ms/step
# Epoch 88/200
# 26/26 - 3s - loss: 4.4416e-04 - val_loss: 9.2696e-04 - 3s/epoch - 131ms/step
# Epoch 89/200
# 26/26 - 3s - loss: 4.5602e-04 - val_loss: 8.1146e-04 - 3s/epoch - 105ms/step
# Epoch 90/200
# 26/26 - 2s - loss: 4.8993e-04 - val_loss: 8.0966e-04 - 2s/epoch - 86ms/step
# Epoch 91/200
# 26/26 - 2s - loss: 5.9984e-04 - val_loss: 8.0847e-04 - 2s/epoch - 85ms/step
# Epoch 92/200
# 26/26 - 2s - loss: 4.3942e-04 - val_loss: 8.0561e-04 - 2s/epoch - 88ms/step
# Epoch 93/200
# 26/26 - 3s - loss: 4.2010e-04 - val_loss: 8.5087e-04 - 3s/epoch - 104ms/step
# Epoch 94/200
# 26/26 - 3s - loss: 4.1852e-04 - val_loss: 7.6392e-04 - 3s/epoch - 133ms/step
# Epoch 95/200
# 26/26 - 2s - loss: 4.4259e-04 - val_loss: 9.3887e-04 - 2s/epoch - 81ms/step
# Epoch 96/200
# 26/26 - 2s - loss: 4.7439e-04 - val_loss: 0.0017 - 2s/epoch - 84ms/step
# Epoch 97/200
# 26/26 - 2s - loss: 5.0821e-04 - val_loss: 7.6519e-04 - 2s/epoch - 88ms/step
# Epoch 98/200
# 26/26 - 2s - loss: 4.7125e-04 - val_loss: 8.3837e-04 - 2s/epoch - 88ms/step
# Epoch 99/200
# 26/26 - 4s - loss: 6.6361e-04 - val_loss: 9.9305e-04 - 4s/epoch - 152ms/step
# Epoch 100/200
# 26/26 - 2s - loss: 4.7362e-04 - val_loss: 7.7708e-04 - 2s/epoch - 83ms/step
# Epoch 101/200
# 26/26 - 2s - loss: 4.5226e-04 - val_loss: 9.2133e-04 - 2s/epoch - 84ms/step
# Epoch 102/200
# 26/26 - 2s - loss: 4.5781e-04 - val_loss: 8.8083e-04 - 2s/epoch - 86ms/step
# Epoch 103/200
# 26/26 - 2s - loss: 4.3590e-04 - val_loss: 8.9121e-04 - 2s/epoch - 85ms/step
# Epoch 104/200
# 26/26 - 3s - loss: 4.1951e-04 - val_loss: 7.5220e-04 - 3s/epoch - 130ms/step
# Epoch 105/200
# 26/26 - 3s - loss: 4.3372e-04 - val_loss: 7.4117e-04 - 3s/epoch - 102ms/step
# Epoch 106/200
# 26/26 - 2s - loss: 5.4883e-04 - val_loss: 0.0011 - 2s/epoch - 89ms/step
# Epoch 107/200
# 26/26 - 2s - loss: 4.5277e-04 - val_loss: 7.3826e-04 - 2s/epoch - 86ms/step
# Epoch 108/200
# 26/26 - 2s - loss: 4.0419e-04 - val_loss: 9.9034e-04 - 2s/epoch - 87ms/step
# Epoch 109/200
# 26/26 - 3s - loss: 5.1007e-04 - val_loss: 0.0018 - 3s/epoch - 103ms/step
# Epoch 110/200
# 26/26 - 3s - loss: 6.8384e-04 - val_loss: 8.3297e-04 - 3s/epoch - 134ms/step
# Epoch 111/200
# 26/26 - 2s - loss: 7.5749e-04 - val_loss: 0.0012 - 2s/epoch - 83ms/step
# Epoch 112/200
# 26/26 - 2s - loss: 5.6412e-04 - val_loss: 9.9904e-04 - 2s/epoch - 85ms/step
# Epoch 113/200
# 26/26 - 2s - loss: 4.3886e-04 - val_loss: 7.7821e-04 - 2s/epoch - 88ms/step
# Epoch 114/200
# 26/26 - 2s - loss: 3.6336e-04 - val_loss: 7.3410e-04 - 2s/epoch - 90ms/step
# Epoch 115/200
# 26/26 - 4s - loss: 3.9640e-04 - val_loss: 6.9046e-04 - 4s/epoch - 155ms/step
# Epoch 116/200
# 26/26 - 2s - loss: 3.7579e-04 - val_loss: 7.5706e-04 - 2s/epoch - 85ms/step
# Epoch 117/200
# 26/26 - 2s - loss: 4.2292e-04 - val_loss: 7.8698e-04 - 2s/epoch - 91ms/step
# Epoch 118/200
# 26/26 - 2s - loss: 4.0894e-04 - val_loss: 7.4577e-04 - 2s/epoch - 88ms/step
# Epoch 119/200
# 26/26 - 2s - loss: 5.0029e-04 - val_loss: 8.1350e-04 - 2s/epoch - 94ms/step
# Epoch 120/200
# 26/26 - 4s - loss: 5.6399e-04 - val_loss: 8.9651e-04 - 4s/epoch - 145ms/step
# Epoch 121/200
# 26/26 - 2s - loss: 4.0232e-04 - val_loss: 0.0010 - 2s/epoch - 86ms/step
# Epoch 122/200
# 26/26 - 2s - loss: 3.7776e-04 - val_loss: 9.1755e-04 - 2s/epoch - 88ms/step
# Epoch 123/200
# 26/26 - 2s - loss: 4.1561e-04 - val_loss: 9.3895e-04 - 2s/epoch - 84ms/step
# Epoch 124/200
# 26/26 - 2s - loss: 4.1259e-04 - val_loss: 0.0016 - 2s/epoch - 85ms/step
# Epoch 125/200
# 26/26 - 3s - loss: 4.8798e-04 - val_loss: 9.9068e-04 - 3s/epoch - 117ms/step
# Epoch 126/200
# 26/26 - 3s - loss: 5.2736e-04 - val_loss: 0.0014 - 3s/epoch - 111ms/step
# Epoch 127/200
# 26/26 - 2s - loss: 5.0229e-04 - val_loss: 0.0010 - 2s/epoch - 84ms/step
# Epoch 128/200
# 26/26 - 2s - loss: 4.3993e-04 - val_loss: 7.1311e-04 - 2s/epoch - 86ms/step
# Epoch 129/200
# 26/26 - 2s - loss: 4.2291e-04 - val_loss: 0.0017 - 2s/epoch - 88ms/step
# Epoch 130/200
# 26/26 - 2s - loss: 4.6243e-04 - val_loss: 0.0012 - 2s/epoch - 89ms/step
# Epoch 131/200
# 26/26 - 4s - loss: 3.7878e-04 - val_loss: 7.7706e-04 - 4s/epoch - 146ms/step
# Epoch 132/200
# 26/26 - 2s - loss: 3.9069e-04 - val_loss: 6.9021e-04 - 2s/epoch - 83ms/step
# Epoch 133/200
# 26/26 - 2s - loss: 3.8594e-04 - val_loss: 7.0292e-04 - 2s/epoch - 90ms/step
# Epoch 134/200
# 26/26 - 2s - loss: 3.8371e-04 - val_loss: 6.9928e-04 - 2s/epoch - 84ms/step
# Epoch 135/200
# 26/26 - 2s - loss: 3.7726e-04 - val_loss: 7.4192e-04 - 2s/epoch - 85ms/step
# Epoch 136/200
# 26/26 - 4s - loss: 4.2799e-04 - val_loss: 0.0013 - 4s/epoch - 148ms/step
# Epoch 137/200
# 26/26 - 2s - loss: 3.5884e-04 - val_loss: 6.6303e-04 - 2s/epoch - 92ms/step
# Epoch 138/200
# 26/26 - 2s - loss: 3.9481e-04 - val_loss: 8.3943e-04 - 2s/epoch - 87ms/step
# Epoch 139/200
# 26/26 - 2s - loss: 3.4188e-04 - val_loss: 9.2102e-04 - 2s/epoch - 83ms/step
# Epoch 140/200
# 26/26 - 2s - loss: 3.8229e-04 - val_loss: 7.1402e-04 - 2s/epoch - 85ms/step
# Epoch 141/200
# 26/26 - 3s - loss: 4.3419e-04 - val_loss: 0.0015 - 3s/epoch - 125ms/step
# Epoch 142/200
# 26/26 - 3s - loss: 4.3720e-04 - val_loss: 6.7755e-04 - 3s/epoch - 111ms/step
# Epoch 143/200
# 26/26 - 2s - loss: 3.9900e-04 - val_loss: 6.9680e-04 - 2s/epoch - 82ms/step
# Epoch 144/200
# 26/26 - 2s - loss: 3.8497e-04 - val_loss: 7.7104e-04 - 2s/epoch - 86ms/step
# Epoch 145/200
# 26/26 - 2s - loss: 4.3273e-04 - val_loss: 9.6840e-04 - 2s/epoch - 85ms/step
# Epoch 146/200
# 26/26 - 2s - loss: 4.3128e-04 - val_loss: 7.0356e-04 - 2s/epoch - 90ms/step
# Epoch 147/200
# 26/26 - 4s - loss: 3.3209e-04 - val_loss: 6.7022e-04 - 4s/epoch - 146ms/step
# Epoch 148/200
# 26/26 - 2s - loss: 3.6991e-04 - val_loss: 7.2782e-04 - 2s/epoch - 89ms/step
# Epoch 149/200
# 26/26 - 2s - loss: 4.6081e-04 - val_loss: 6.4518e-04 - 2s/epoch - 82ms/step
# Epoch 150/200
# 26/26 - 2s - loss: 3.6959e-04 - val_loss: 7.3513e-04 - 2s/epoch - 82ms/step
# Epoch 151/200
# 26/26 - 2s - loss: 3.5481e-04 - val_loss: 7.8028e-04 - 2s/epoch - 87ms/step
# Epoch 152/200
# 26/26 - 4s - loss: 3.5358e-04 - val_loss: 0.0014 - 4s/epoch - 140ms/step
# Epoch 153/200
# 26/26 - 2s - loss: 3.7723e-04 - val_loss: 6.4714e-04 - 2s/epoch - 96ms/step
# Epoch 154/200
# 26/26 - 2s - loss: 3.5635e-04 - val_loss: 6.9316e-04 - 2s/epoch - 82ms/step
# Epoch 155/200
# 26/26 - 2s - loss: 3.6826e-04 - val_loss: 8.0670e-04 - 2s/epoch - 82ms/step
# Epoch 156/200
# 26/26 - 2s - loss: 4.3717e-04 - val_loss: 6.9730e-04 - 2s/epoch - 86ms/step
# Epoch 157/200
# 26/26 - 2s - loss: 3.7824e-04 - val_loss: 9.2245e-04 - 2s/epoch - 89ms/step
# Epoch 158/200
# 26/26 - 4s - loss: 3.6441e-04 - val_loss: 6.9221e-04 - 4s/epoch - 135ms/step
# Epoch 159/200
# 26/26 - 2s - loss: 4.3685e-04 - val_loss: 0.0010 - 2s/epoch - 83ms/step
# Epoch 160/200
# 26/26 - 2s - loss: 3.7959e-04 - val_loss: 9.3856e-04 - 2s/epoch - 88ms/step
# Epoch 161/200
# 26/26 - 2s - loss: 4.2884e-04 - val_loss: 6.4297e-04 - 2s/epoch - 91ms/step
# Epoch 162/200
# 26/26 - 2s - loss: 3.3584e-04 - val_loss: 6.4184e-04 - 2s/epoch - 84ms/step
# Epoch 163/200
# 26/26 - 4s - loss: 3.4002e-04 - val_loss: 6.6309e-04 - 4s/epoch - 157ms/step
# Epoch 164/200
# 26/26 - 2s - loss: 3.5338e-04 - val_loss: 0.0012 - 2s/epoch - 88ms/step
# Epoch 165/200
# 26/26 - 2s - loss: 3.2425e-04 - val_loss: 9.2501e-04 - 2s/epoch - 85ms/step
# Epoch 166/200
# 26/26 - 2s - loss: 3.8047e-04 - val_loss: 0.0010 - 2s/epoch - 87ms/step
# Epoch 167/200
# 26/26 - 2s - loss: 3.3305e-04 - val_loss: 7.4339e-04 - 2s/epoch - 86ms/step
# Epoch 168/200
# 26/26 - 3s - loss: 3.2998e-04 - val_loss: 7.0277e-04 - 3s/epoch - 134ms/step
# Epoch 169/200
# 26/26 - 3s - loss: 3.4492e-04 - val_loss: 7.5664e-04 - 3s/epoch - 103ms/step
# Epoch 170/200
# 26/26 - 2s - loss: 3.2458e-04 - val_loss: 6.1292e-04 - 2s/epoch - 86ms/step
# Epoch 171/200
# 26/26 - 2s - loss: 3.1410e-04 - val_loss: 5.9991e-04 - 2s/epoch - 84ms/step
# Epoch 172/200
# 26/26 - 2s - loss: 3.1304e-04 - val_loss: 6.0772e-04 - 2s/epoch - 87ms/step
# Epoch 173/200
# 26/26 - 2s - loss: 3.2661e-04 - val_loss: 7.2653e-04 - 2s/epoch - 96ms/step
# Epoch 174/200
# 26/26 - 4s - loss: 3.3266e-04 - val_loss: 9.4726e-04 - 4s/epoch - 135ms/step
# Epoch 175/200
# 26/26 - 2s - loss: 3.7707e-04 - val_loss: 7.1684e-04 - 2s/epoch - 82ms/step
# Epoch 176/200
# 26/26 - 2s - loss: 3.7006e-04 - val_loss: 6.3005e-04 - 2s/epoch - 82ms/step
# Epoch 177/200
# 26/26 - 2s - loss: 3.2182e-04 - val_loss: 0.0012 - 2s/epoch - 88ms/step
# Epoch 178/200
# 26/26 - 2s - loss: 3.9139e-04 - val_loss: 6.6612e-04 - 2s/epoch - 82ms/step
# Epoch 179/200
# 26/26 - 4s - loss: 3.9219e-04 - val_loss: 6.9729e-04 - 4s/epoch - 135ms/step
# Epoch 180/200
# 26/26 - 2s - loss: 3.8878e-04 - val_loss: 8.0249e-04 - 2s/epoch - 93ms/step
# Epoch 181/200
# 26/26 - 2s - loss: 3.6441e-04 - val_loss: 6.1713e-04 - 2s/epoch - 86ms/step
# Epoch 182/200
# 26/26 - 2s - loss: 3.6908e-04 - val_loss: 5.9956e-04 - 2s/epoch - 84ms/step
# Epoch 183/200
# 26/26 - 2s - loss: 4.8367e-04 - val_loss: 5.9912e-04 - 2s/epoch - 83ms/step
# Epoch 184/200
# 26/26 - 3s - loss: 3.4623e-04 - val_loss: 7.5296e-04 - 3s/epoch - 99ms/step
# Epoch 185/200
# 26/26 - 3s - loss: 3.6783e-04 - val_loss: 6.8191e-04 - 3s/epoch - 132ms/step
# Epoch 186/200
# 26/26 - 2s - loss: 3.3999e-04 - val_loss: 6.9275e-04 - 2s/epoch - 86ms/step
# Epoch 187/200
# 26/26 - 2s - loss: 3.7052e-04 - val_loss: 6.0853e-04 - 2s/epoch - 82ms/step
# Epoch 188/200
# 26/26 - 2s - loss: 3.0083e-04 - val_loss: 5.8336e-04 - 2s/epoch - 84ms/step
# Epoch 189/200
# 26/26 - 2s - loss: 2.9717e-04 - val_loss: 8.0602e-04 - 2s/epoch - 88ms/step
# Epoch 190/200
# 26/26 - 4s - loss: 3.3098e-04 - val_loss: 0.0011 - 4s/epoch - 142ms/step
# Epoch 191/200
# 26/26 - 2s - loss: 3.4271e-04 - val_loss: 8.0171e-04 - 2s/epoch - 91ms/step
# Epoch 192/200
# 26/26 - 2s - loss: 3.0505e-04 - val_loss: 5.8706e-04 - 2s/epoch - 86ms/step
# Epoch 193/200
# 26/26 - 2s - loss: 2.8675e-04 - val_loss: 5.6543e-04 - 2s/epoch - 79ms/step
# Epoch 194/200
# 26/26 - 2s - loss: 3.0032e-04 - val_loss: 5.9795e-04 - 2s/epoch - 87ms/step
# Epoch 195/200
# 26/26 - 3s - loss: 3.8689e-04 - val_loss: 6.0240e-04 - 3s/epoch - 120ms/step
# Epoch 196/200
# 26/26 - 3s - loss: 3.0028e-04 - val_loss: 6.8882e-04 - 3s/epoch - 114ms/step
# Epoch 197/200
# 26/26 - 2s - loss: 3.1106e-04 - val_loss: 7.4530e-04 - 2s/epoch - 89ms/step
# Epoch 198/200
# 26/26 - 2s - loss: 4.4158e-04 - val_loss: 5.7369e-04 - 2s/epoch - 89ms/step
# Epoch 199/200
# 26/26 - 2s - loss: 3.6460e-04 - val_loss: 6.2657e-04 - 2s/epoch - 88ms/step
# Epoch 200/200
# 26/26 - 2s - loss: 2.9638e-04 - val_loss: 6.6153e-04 - 2s/epoch - 88ms/step

# %% [markdown]
# Dividing Test values into groups

# %% [markdown]
# Prediction

# %%
predicted_price = algo.predict(x_test)
predicted_price = sc.inverse_transform(predicted_price)
# Out:
# 8/8 [==============================] - 1s 12ms/step

# %%
df.reset_index(inplace=True)
plt.plot(df.loc[:t_size+1,'Date'],df.loc[:t_size+1,'Open'], color='green',label="Train data")
plt.plot(df.loc[t_size:, 'Date'],data_test, color = 'red', label = 'Test Data')
plt.plot(df.loc[t_size:, 'Date'],predicted_price, color = 'blue', label = 'Predicted Data')
plt.xticks(np.arange(0,df.shape[0],250))
plt.title('Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel('Stock Price')
plt.legend()
plt.show()

# %%
plt.plot(df.loc[:t_size+1,'Date'],df.loc[:t_size+1,'Open'], color='green',label="Train data")

plt.xticks(np.arange(0,df.shape[0],250))
plt.title('Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel('Stock Price')
plt.legend()
plt.show()

# %%
plt.plot(df.loc[t_size:, 'Date'],data_test, color = 'red', label = 'Test Data')
plt.plot(df.loc[t_size:, 'Date'],predicted_price, color = 'blue', label = 'Predicted Data')
plt.xticks(np.arange(0,x_test.shape[0],50))
plt.title('Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel('Stock Price')
plt.legend()
plt.show()

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error
import numpy as np

mae = mean_absolute_error(data_test,predicted_price)

mse = mean_squared_error(data_test, predicted_price)

rmse = np.sqrt(mse)

print(f'Mean Absolute Error (MAE): {mae:.2f}')
print(f'Mean Squared Error (MSE): {mse:.2f}')
print(f'Root Mean Squared Error (RMSE): {rmse:.2f}')
# Out:
# Mean Absolute Error (MAE): 4.62
# Mean Squared Error (MSE): 32.24
# Root Mean Squared Error (RMSE): 5.68

# %% [markdown]
# Predict Future

# %%
test2=data_test.copy()
for i in range(f_size):
  X=test2[-w_size:]
  X=X.reshape(w_size,1)
  X=sc.fit_transform(X)

  X=np.reshape(X,(1,w_size,1))

  close=algo.predict(X)
  y=sc.inverse_transform(close)

  test2=np.append(test2, y)
# Out:
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step

# %%
from datetime import datetime, timedelta
x=df.loc[-1:, 'Date']
day=x[len(x)-1]
date_obj = datetime.strptime(day, '%Y-%m-%d')
start_date = date_obj
date_list = [(start_date + timedelta(days=i)).strftime('%Y-%m-%d') for i in range(f_size)]

# %%
forcasted_data=test2[-f_size:]
plt.plot(date_list,forcasted_data,color="#123692", label="Future data")
plt.xticks(np.arange(0,len(forcasted_data),f_size))
plt.show()

# %%
plt.plot(df.loc[:t_size,'Date'],df.loc[:t_size,'Open'], color='green',label="Train data")
plt.plot(df.loc[t_size:, 'Date'],data_test, color = 'red', label = 'Test Data')
plt.plot(df.loc[t_size:, 'Date'],predicted_price, color = 'blue', label = 'Predicted Data')
plt.plot(date_list,forcasted_data,color='yellow', label="Future data")
plt.xticks(np.arange(0,df.shape[0],250))
plt.title('Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel('Stock Price')
plt.legend()
plt.show()

# %%
plt.plot(df.loc[t_size:, 'Date'],data_test, color = 'red', label = 'Test Data')
plt.plot(df.loc[t_size:, 'Date'],predicted_price, color = 'blue', label = 'Predicted Data')
plt.plot(date_list,forcasted_data,color='yellow', label="Future data")
plt.xticks(np.arange(0,x_test.shape[0],50))
plt.title('Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel('Stock Price')
plt.legend()
plt.show()

# %%
algo2 = Sequential()
algo2.add(Bidirectional(LSTM(60,return_sequences=True,activation='relu',input_shape = (x_train.shape[1], 1),kernel_initializer=initializer)))
algo2.add(Dropout(0.2))
algo2.add(Bidirectional(LSTM(60)))
algo2.add(Dense(1))
algo2.compile(optimizer = 'adam', loss = 'mean_squared_error')
# Out:
# WARNING:tensorflow:Layer lstm_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.

# %%
algo2.fit(x_train, y_train, epochs = 50, batch_size = b_size, validation_split=0.15,verbose=2)
# Out:
# Epoch 1/50
# 26/26 - 11s - loss: 0.0659 - val_loss: 0.0053 - 11s/epoch - 411ms/step
# Epoch 2/50
# 26/26 - 2s - loss: 0.0042 - val_loss: 0.0054 - 2s/epoch - 84ms/step
# Epoch 3/50
# 26/26 - 2s - loss: 0.0020 - val_loss: 0.0057 - 2s/epoch - 84ms/step
# Epoch 4/50
# 26/26 - 2s - loss: 0.0017 - val_loss: 0.0048 - 2s/epoch - 83ms/step
# Epoch 5/50
# 26/26 - 2s - loss: 0.0015 - val_loss: 0.0040 - 2s/epoch - 82ms/step
# Epoch 6/50
# 26/26 - 4s - loss: 0.0015 - val_loss: 0.0043 - 4s/epoch - 139ms/step
# Epoch 7/50
# 26/26 - 2s - loss: 0.0014 - val_loss: 0.0043 - 2s/epoch - 91ms/step
# Epoch 8/50
# 26/26 - 2s - loss: 0.0014 - val_loss: 0.0040 - 2s/epoch - 90ms/step
# Epoch 9/50
# 26/26 - 2s - loss: 0.0012 - val_loss: 0.0038 - 2s/epoch - 83ms/step
# Epoch 10/50
# 26/26 - 2s - loss: 0.0011 - val_loss: 0.0029 - 2s/epoch - 87ms/step
# Epoch 11/50
# 26/26 - 3s - loss: 0.0012 - val_loss: 0.0033 - 3s/epoch - 111ms/step
# Epoch 12/50
# 26/26 - 4s - loss: 0.0012 - val_loss: 0.0045 - 4s/epoch - 136ms/step
# Epoch 13/50
# 26/26 - 2s - loss: 0.0010 - val_loss: 0.0035 - 2s/epoch - 87ms/step
# Epoch 14/50
# 26/26 - 2s - loss: 8.9655e-04 - val_loss: 0.0022 - 2s/epoch - 87ms/step
# Epoch 15/50
# 26/26 - 2s - loss: 0.0011 - val_loss: 0.0021 - 2s/epoch - 94ms/step
# Epoch 16/50
# 26/26 - 2s - loss: 9.2777e-04 - val_loss: 0.0020 - 2s/epoch - 96ms/step
# Epoch 17/50
# 26/26 - 4s - loss: 8.3493e-04 - val_loss: 0.0023 - 4s/epoch - 142ms/step
# Epoch 18/50
# 26/26 - 2s - loss: 8.2254e-04 - val_loss: 0.0020 - 2s/epoch - 87ms/step
# Epoch 19/50
# 26/26 - 2s - loss: 7.9410e-04 - val_loss: 0.0017 - 2s/epoch - 85ms/step
# Epoch 20/50
# 26/26 - 2s - loss: 7.5953e-04 - val_loss: 0.0017 - 2s/epoch - 86ms/step
# Epoch 21/50
# 26/26 - 2s - loss: 7.8321e-04 - val_loss: 0.0025 - 2s/epoch - 89ms/step
# Epoch 22/50
# 26/26 - 4s - loss: 7.2065e-04 - val_loss: 0.0017 - 4s/epoch - 137ms/step
# Epoch 23/50
# 26/26 - 2s - loss: 7.7747e-04 - val_loss: 0.0015 - 2s/epoch - 90ms/step
# Epoch 24/50
# 26/26 - 2s - loss: 7.7183e-04 - val_loss: 0.0014 - 2s/epoch - 85ms/step
# Epoch 25/50
# 26/26 - 2s - loss: 7.1152e-04 - val_loss: 0.0014 - 2s/epoch - 90ms/step
# Epoch 26/50
# 26/26 - 2s - loss: 7.3897e-04 - val_loss: 0.0016 - 2s/epoch - 89ms/step
# Epoch 27/50
# 26/26 - 3s - loss: 6.6645e-04 - val_loss: 0.0014 - 3s/epoch - 120ms/step
# Epoch 28/50
# 26/26 - 3s - loss: 6.7158e-04 - val_loss: 0.0012 - 3s/epoch - 117ms/step
# Epoch 29/50
# 26/26 - 2s - loss: 6.9901e-04 - val_loss: 0.0017 - 2s/epoch - 84ms/step
# Epoch 30/50
# 26/26 - 2s - loss: 6.7485e-04 - val_loss: 0.0018 - 2s/epoch - 89ms/step
# Epoch 31/50
# 26/26 - 2s - loss: 6.3593e-04 - val_loss: 0.0013 - 2s/epoch - 86ms/step
# Epoch 32/50
# 26/26 - 3s - loss: 7.2126e-04 - val_loss: 0.0024 - 3s/epoch - 104ms/step
# Epoch 33/50
# 26/26 - 3s - loss: 7.0113e-04 - val_loss: 0.0015 - 3s/epoch - 113ms/step
# Epoch 34/50
# 26/26 - 2s - loss: 7.4937e-04 - val_loss: 0.0012 - 2s/epoch - 92ms/step
# Epoch 35/50
# 26/26 - 2s - loss: 5.8817e-04 - val_loss: 0.0014 - 2s/epoch - 87ms/step
# Epoch 36/50
# 26/26 - 2s - loss: 6.5212e-04 - val_loss: 0.0023 - 2s/epoch - 88ms/step
# Epoch 37/50
# 26/26 - 3s - loss: 6.5167e-04 - val_loss: 0.0013 - 3s/epoch - 116ms/step
# Epoch 38/50
# 26/26 - 3s - loss: 6.0962e-04 - val_loss: 0.0020 - 3s/epoch - 123ms/step
# Epoch 39/50
# 26/26 - 2s - loss: 6.2408e-04 - val_loss: 0.0011 - 2s/epoch - 87ms/step
# Epoch 40/50
# 26/26 - 2s - loss: 5.6718e-04 - val_loss: 0.0012 - 2s/epoch - 88ms/step
# Epoch 41/50
# 26/26 - 2s - loss: 6.1979e-04 - val_loss: 0.0012 - 2s/epoch - 87ms/step
# Epoch 42/50
# 26/26 - 2s - loss: 5.9323e-04 - val_loss: 0.0011 - 2s/epoch - 88ms/step
# Epoch 43/50
# 26/26 - 4s - loss: 5.8111e-04 - val_loss: 0.0011 - 4s/epoch - 145ms/step
# Epoch 44/50
# 26/26 - 2s - loss: 5.4257e-04 - val_loss: 0.0013 - 2s/epoch - 85ms/step
# Epoch 45/50
# 26/26 - 2s - loss: 5.3995e-04 - val_loss: 0.0013 - 2s/epoch - 89ms/step
# Epoch 46/50
# 26/26 - 2s - loss: 5.9648e-04 - val_loss: 0.0010 - 2s/epoch - 83ms/step
# Epoch 47/50
# 26/26 - 2s - loss: 5.1221e-04 - val_loss: 0.0011 - 2s/epoch - 86ms/step
# Epoch 48/50
# 26/26 - 4s - loss: 6.1862e-04 - val_loss: 0.0017 - 4s/epoch - 147ms/step
# Epoch 49/50
# 26/26 - 2s - loss: 5.5257e-04 - val_loss: 0.0011 - 2s/epoch - 95ms/step
# Epoch 50/50
# 26/26 - 2s - loss: 4.9279e-04 - val_loss: 9.8133e-04 - 2s/epoch - 88ms/step

# %%
predicted_price2 = algo2.predict(x_test)
predicted_price2 = sc.inverse_transform(predicted_price2)
# Out:
# 8/8 [==============================] - 1s 12ms/step

# %%
mae_2 = mean_absolute_error(data_test,predicted_price2)

mse_2 = mean_squared_error(data_test, predicted_price2)

rmse_2 = np.sqrt(mse_2)

print(f'Mean Absolute Error (MAE): {mae_2:.2f}')
print(f'Mean Squared Error (MSE): {mse_2:.2f}')
print(f'Root Mean Squared Error (RMSE): {rmse_2:.2f}')
# Out:
# Mean Absolute Error (MAE): 21.56
# Mean Squared Error (MSE): 703.11
# Root Mean Squared Error (RMSE): 26.52

# %%
algo3 = Sequential()
algo3.add(Bidirectional(LSTM(30,return_sequences=True,activation='relu',input_shape = (x_train.shape[1], 1),kernel_initializer=initializer)))
algo3.add(Dropout(0.2))
algo3.add(Bidirectional(LSTM(120)))
algo3.add(Dense(1))
algo3.compile(optimizer = 'adam', loss = 'mean_squared_error')
algo3.fit(x_train, y_train, epochs = 75, batch_size = b_size, validation_split=0.15,verbose=2)
# Out:
# WARNING:tensorflow:Layer lstm_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Epoch 1/75
# 26/26 - 11s - loss: 0.0699 - val_loss: 0.0156 - 11s/epoch - 425ms/step
# Epoch 2/75
# 26/26 - 2s - loss: 0.0043 - val_loss: 0.0065 - 2s/epoch - 91ms/step
# Epoch 3/75
# 26/26 - 2s - loss: 0.0021 - val_loss: 0.0065 - 2s/epoch - 91ms/step
# Epoch 4/75
# 26/26 - 2s - loss: 0.0018 - val_loss: 0.0046 - 2s/epoch - 88ms/step
# Epoch 5/75
# 26/26 - 3s - loss: 0.0017 - val_loss: 0.0050 - 3s/epoch - 119ms/step
# Epoch 6/75
# 26/26 - 3s - loss: 0.0017 - val_loss: 0.0041 - 3s/epoch - 114ms/step
# Epoch 7/75
# 26/26 - 2s - loss: 0.0016 - val_loss: 0.0049 - 2s/epoch - 91ms/step
# Epoch 8/75
# 26/26 - 2s - loss: 0.0016 - val_loss: 0.0049 - 2s/epoch - 88ms/step
# Epoch 9/75
# 26/26 - 2s - loss: 0.0016 - val_loss: 0.0033 - 2s/epoch - 86ms/step
# Epoch 10/75
# 26/26 - 3s - loss: 0.0015 - val_loss: 0.0055 - 3s/epoch - 116ms/step
# Epoch 11/75
# 26/26 - 3s - loss: 0.0015 - val_loss: 0.0033 - 3s/epoch - 125ms/step
# Epoch 12/75
# 26/26 - 2s - loss: 0.0014 - val_loss: 0.0033 - 2s/epoch - 92ms/step
# Epoch 13/75
# 26/26 - 2s - loss: 0.0013 - val_loss: 0.0025 - 2s/epoch - 92ms/step
# Epoch 14/75
# 26/26 - 2s - loss: 0.0016 - val_loss: 0.0035 - 2s/epoch - 89ms/step
# Epoch 15/75
# 26/26 - 3s - loss: 0.0018 - val_loss: 0.0026 - 3s/epoch - 97ms/step
# Epoch 16/75
# 26/26 - 4s - loss: 0.0012 - val_loss: 0.0033 - 4s/epoch - 141ms/step
# Epoch 17/75
# 26/26 - 2s - loss: 0.0011 - val_loss: 0.0024 - 2s/epoch - 86ms/step
# Epoch 18/75
# 26/26 - 2s - loss: 0.0011 - val_loss: 0.0022 - 2s/epoch - 88ms/step
# Epoch 19/75
# 26/26 - 2s - loss: 0.0011 - val_loss: 0.0031 - 2s/epoch - 89ms/step
# Epoch 20/75
# 26/26 - 2s - loss: 0.0012 - val_loss: 0.0019 - 2s/epoch - 85ms/step
# Epoch 21/75
# 26/26 - 4s - loss: 0.0010 - val_loss: 0.0017 - 4s/epoch - 148ms/step
# Epoch 22/75
# 26/26 - 2s - loss: 0.0012 - val_loss: 0.0017 - 2s/epoch - 88ms/step
# Epoch 23/75
# 26/26 - 2s - loss: 0.0011 - val_loss: 0.0031 - 2s/epoch - 90ms/step
# Epoch 24/75
# 26/26 - 2s - loss: 0.0012 - val_loss: 0.0018 - 2s/epoch - 90ms/step
# Epoch 25/75
# 26/26 - 2s - loss: 9.1936e-04 - val_loss: 0.0017 - 2s/epoch - 85ms/step
# Epoch 26/75
# 26/26 - 4s - loss: 8.9103e-04 - val_loss: 0.0016 - 4s/epoch - 136ms/step
# Epoch 27/75
# 26/26 - 3s - loss: 8.4165e-04 - val_loss: 0.0015 - 3s/epoch - 103ms/step
# Epoch 28/75
# 26/26 - 2s - loss: 9.2461e-04 - val_loss: 0.0022 - 2s/epoch - 85ms/step
# Epoch 29/75
# 26/26 - 2s - loss: 9.0524e-04 - val_loss: 0.0019 - 2s/epoch - 89ms/step
# Epoch 30/75
# 26/26 - 2s - loss: 8.9240e-04 - val_loss: 0.0015 - 2s/epoch - 90ms/step
# Epoch 31/75
# 26/26 - 3s - loss: 9.6649e-04 - val_loss: 0.0015 - 3s/epoch - 119ms/step
# Epoch 32/75
# 26/26 - 3s - loss: 9.0109e-04 - val_loss: 0.0020 - 3s/epoch - 123ms/step
# Epoch 33/75
# 26/26 - 2s - loss: 8.9208e-04 - val_loss: 0.0024 - 2s/epoch - 84ms/step
# Epoch 34/75
# 26/26 - 2s - loss: 9.0783e-04 - val_loss: 0.0019 - 2s/epoch - 84ms/step
# Epoch 35/75
# 26/26 - 2s - loss: 7.6485e-04 - val_loss: 0.0014 - 2s/epoch - 89ms/step
# Epoch 36/75
# 26/26 - 2s - loss: 8.7802e-04 - val_loss: 0.0014 - 2s/epoch - 88ms/step
# Epoch 37/75
# 26/26 - 4s - loss: 9.2474e-04 - val_loss: 0.0020 - 4s/epoch - 144ms/step
# Epoch 38/75
# 26/26 - 2s - loss: 8.1615e-04 - val_loss: 0.0017 - 2s/epoch - 90ms/step
# Epoch 39/75
# 26/26 - 2s - loss: 0.0011 - val_loss: 0.0014 - 2s/epoch - 94ms/step
# Epoch 40/75
# 26/26 - 2s - loss: 8.9607e-04 - val_loss: 0.0029 - 2s/epoch - 84ms/step
# Epoch 41/75
# 26/26 - 2s - loss: 9.4507e-04 - val_loss: 0.0027 - 2s/epoch - 82ms/step
# Epoch 42/75
# 26/26 - 4s - loss: 8.6152e-04 - val_loss: 0.0014 - 4s/epoch - 150ms/step
# Epoch 43/75
# 26/26 - 2s - loss: 7.1275e-04 - val_loss: 0.0013 - 2s/epoch - 85ms/step
# Epoch 44/75
# 26/26 - 2s - loss: 7.9864e-04 - val_loss: 0.0013 - 2s/epoch - 89ms/step
# Epoch 45/75
# 26/26 - 2s - loss: 6.8207e-04 - val_loss: 0.0013 - 2s/epoch - 88ms/step
# Epoch 46/75
# 26/26 - 2s - loss: 7.2303e-04 - val_loss: 0.0014 - 2s/epoch - 85ms/step
# Epoch 47/75
# 26/26 - 3s - loss: 7.3495e-04 - val_loss: 0.0012 - 3s/epoch - 127ms/step
# Epoch 48/75
# 26/26 - 3s - loss: 7.9316e-04 - val_loss: 0.0013 - 3s/epoch - 105ms/step
# Epoch 49/75
# 26/26 - 2s - loss: 9.8881e-04 - val_loss: 0.0013 - 2s/epoch - 92ms/step
# Epoch 50/75
# 26/26 - 2s - loss: 6.7708e-04 - val_loss: 0.0016 - 2s/epoch - 85ms/step
# Epoch 51/75
# 26/26 - 2s - loss: 6.9428e-04 - val_loss: 0.0012 - 2s/epoch - 87ms/step
# Epoch 52/75
# 26/26 - 3s - loss: 6.9203e-04 - val_loss: 0.0015 - 3s/epoch - 106ms/step
# Epoch 53/75
# 26/26 - 3s - loss: 6.8899e-04 - val_loss: 0.0012 - 3s/epoch - 134ms/step
# Epoch 54/75
# 26/26 - 2s - loss: 8.9355e-04 - val_loss: 0.0013 - 2s/epoch - 84ms/step
# Epoch 55/75
# 26/26 - 2s - loss: 7.3660e-04 - val_loss: 0.0011 - 2s/epoch - 88ms/step
# Epoch 56/75
# 26/26 - 2s - loss: 8.4550e-04 - val_loss: 0.0022 - 2s/epoch - 86ms/step
# Epoch 57/75
# 26/26 - 2s - loss: 9.4071e-04 - val_loss: 0.0019 - 2s/epoch - 88ms/step
# Epoch 58/75
# 26/26 - 4s - loss: 7.7120e-04 - val_loss: 0.0012 - 4s/epoch - 151ms/step
# Epoch 59/75
# 26/26 - 2s - loss: 0.0011 - val_loss: 0.0014 - 2s/epoch - 93ms/step
# Epoch 60/75
# 26/26 - 2s - loss: 7.3532e-04 - val_loss: 0.0012 - 2s/epoch - 89ms/step
# Epoch 61/75
# 26/26 - 2s - loss: 6.7562e-04 - val_loss: 0.0012 - 2s/epoch - 90ms/step
# Epoch 62/75
# 26/26 - 2s - loss: 6.6001e-04 - val_loss: 0.0017 - 2s/epoch - 90ms/step
# Epoch 63/75
# 26/26 - 4s - loss: 6.6966e-04 - val_loss: 0.0014 - 4s/epoch - 145ms/step
# Epoch 64/75
# 26/26 - 2s - loss: 7.5495e-04 - val_loss: 0.0011 - 2s/epoch - 89ms/step
# Epoch 65/75
# 26/26 - 2s - loss: 7.1134e-04 - val_loss: 0.0011 - 2s/epoch - 91ms/step
# Epoch 66/75
# 26/26 - 2s - loss: 6.7982e-04 - val_loss: 0.0011 - 2s/epoch - 85ms/step
# Epoch 67/75
# 26/26 - 2s - loss: 5.9853e-04 - val_loss: 0.0013 - 2s/epoch - 88ms/step
# Epoch 68/75
# 26/26 - 3s - loss: 6.5407e-04 - val_loss: 0.0011 - 3s/epoch - 130ms/step
# Epoch 69/75
# 26/26 - 3s - loss: 6.8501e-04 - val_loss: 0.0013 - 3s/epoch - 102ms/step
# Epoch 70/75
# 26/26 - 2s - loss: 5.6281e-04 - val_loss: 0.0010 - 2s/epoch - 88ms/step
# Epoch 71/75
# 26/26 - 2s - loss: 5.5794e-04 - val_loss: 0.0015 - 2s/epoch - 89ms/step
# Epoch 72/75
# 26/26 - 2s - loss: 7.6355e-04 - val_loss: 0.0011 - 2s/epoch - 88ms/step
# Epoch 73/75
# 26/26 - 3s - loss: 7.0089e-04 - val_loss: 0.0011 - 3s/epoch - 114ms/step
# Epoch 74/75
# 26/26 - 3s - loss: 6.1845e-04 - val_loss: 0.0012 - 3s/epoch - 124ms/step
# Epoch 75/75
# 26/26 - 2s - loss: 7.6591e-04 - val_loss: 0.0015 - 2s/epoch - 92ms/step

# %%
predicted_price3 = algo3.predict(x_test)
predicted_price3 = sc.inverse_transform(predicted_price3)
# Out:
# 8/8 [==============================] - 1s 12ms/step

# %%
mae_3 = mean_absolute_error(data_test,predicted_price3)

mse_3 = mean_squared_error(data_test, predicted_price3)

rmse_3 = np.sqrt(mse_3)

print(f'Mean Absolute Error (MAE): {mae_3:.2f}')
print(f'Mean Squared Error (MSE): {mse_3:.2f}')
print(f'Root Mean Squared Error (RMSE): {rmse_3:.2f}')
# Out:
# Mean Absolute Error (MAE): 21.19
# Mean Squared Error (MSE): 685.80
# Root Mean Squared Error (RMSE): 26.19
