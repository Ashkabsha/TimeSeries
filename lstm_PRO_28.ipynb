# %% [markdown]
# <a href="https://colab.research.google.com/github/Ashkabsha/TimeSeries/blob/main/lstm_PRO_28.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Importing Packages

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout
import yfinance as yf
from keras.initializers import RandomNormal

# %%
stock_symbol = 'TSLA'
df = yf.download(stock_symbol,period="60mo",interval="1d")
print(df.head())
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                  Open       High        Low      Close  Adj Close     Volume
# Date
# 2018-11-28  23.066000  23.218666  22.813999  23.191334  23.191334   61914000
# 2018-11-29  23.133333  23.166668  22.636667  22.744667  22.744667   46210500
# 2018-11-30  22.788668  23.440001  22.550667  23.365334  23.365334   84436500
# 2018-12-03  24.000000  24.400000  23.466667  23.899332  23.899332  124597500
# 2018-12-04  23.736668  24.578667  23.466667  23.980000  23.980000  126928500

# %% [markdown]
# Importing Data

# %%
df.index = df.index.strftime('%Y-%m-%d')

# %%
df
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2018-11-28   23.066000   23.218666   22.813999   23.191334   23.191334
# 2018-11-29   23.133333   23.166668   22.636667   22.744667   22.744667
# 2018-11-30   22.788668   23.440001   22.550667   23.365334   23.365334
# 2018-12-03   24.000000   24.400000   23.466667   23.899332   23.899332
# 2018-12-04   23.736668   24.578667   23.466667   23.980000   23.980000
# ...                ...         ...         ...         ...         ...
# 2023-11-20  234.039993  237.100006  231.020004  235.600006  235.600006
# 2023-11-21  235.039993  243.619995  233.339996  241.199997  241.199997
# 2023-11-22  242.039993  244.009995  231.399994  234.210007  234.210007
# 2023-11-24  233.750000  238.750000  232.330002  235.449997  235.449997
# 2023-11-27  236.889999  238.330002  232.100006  236.080002  236.080002
#
#                Volume
# Date
# 2018-11-28   61914000
# 2018-11-29   46210500
# 2018-11-30   84436500
# 2018-12-03  124597500
# 2018-12-04  126928500
# ...               ...
# 2023-11-20  116320100
# 2023-11-21  122288000
# 2023-11-22  117950600
# 2023-11-24   65125200
# 2023-11-27  111861000
#
# [1257 rows x 6 columns]

# %%
len(df)
# Out:
# 1257

# %%
df['Open'].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
b_size=32
epoch=200
train_per=0.8
w_size=30
f_size=10

# %%
t_size=int(len(df)*train_per)

# %% [markdown]
# Train-Test Split

# %% [markdown]
# Normalization

# %%
sc = MinMaxScaler(feature_range = (0, 1))

# %% [markdown]
# Create target values

# %%
data_train = df.iloc[:t_size, 1:2].values
data_test = df.iloc[t_size:, 1:2].values
data_total = df.iloc[:,1:2]#open price
sc = MinMaxScaler(feature_range = (0, 1))
training_scaled = sc.fit_transform(data_train)

#Train Data
x_train = []
y_train = []
for iter in range(w_size, t_size):
    x_train.append(training_scaled[iter-w_size:iter, 0])
    y_train.append(training_scaled[iter, 0])
x_train, y_train=np.array(x_train), np.array(y_train)
x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))


#Test data
total_input = data_total[len(data_total) - len(data_test) - w_size:].values
total_input = total_input.reshape(-1, 1)
total_input = sc.transform(total_input)
x_test = []
y_test=[]

# Calculate the maximum number of blocks of length w_size that can be created
blocks = len(total_input) - w_size

for iter in range(blocks):
    x_test.append(total_input[iter:iter+w_size, 0])
    y_test.append(total_input[iter+w_size, 0])     #new addition

x_test = np.array(x_test)
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1))

# %% [markdown]
# Defining Model

# %%
initializer = RandomNormal(mean=0.0, stddev=0.05)
algo = Sequential()
algo.add(LSTM(units = 60, return_sequences = True, input_shape = (x_train.shape[1], 1),kernel_initializer=initializer))
algo.add(Dropout(0.2))
algo.add(LSTM(units = 60))
#algo.add(Dropout(0.2))
algo.add(Dense(units = 1))
algo.compile(optimizer = 'adam', loss = 'mean_squared_error')
print(algo.summary())
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_8 (LSTM)               (None, 30, 60)            14880
#
#  dropout_7 (Dropout)         (None, 30, 60)            0
#
#  lstm_9 (LSTM)               (None, 60)                29040
#
#  dense_3 (Dense)             (None, 1)                 61
#
# =================================================================
# Total params: 43981 (171.80 KB)
# Trainable params: 43981 (171.80 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None

# %% [markdown]
# Training Model

# %%
algo.fit(x_train, y_train, epochs = epoch, batch_size = b_size, validation_split=0.15,verbose=2)
# Out:
# Epoch 1/200
# 26/26 - 4s - loss: 0.0414 - val_loss: 0.0219 - 4s/epoch - 158ms/step
# Epoch 2/200
# 26/26 - 0s - loss: 0.0039 - val_loss: 0.0038 - 207ms/epoch - 8ms/step
# Epoch 3/200
# 26/26 - 0s - loss: 0.0024 - val_loss: 0.0043 - 242ms/epoch - 9ms/step
# Epoch 4/200
# 26/26 - 0s - loss: 0.0022 - val_loss: 0.0051 - 260ms/epoch - 10ms/step
# Epoch 5/200
# 26/26 - 0s - loss: 0.0022 - val_loss: 0.0042 - 258ms/epoch - 10ms/step
# Epoch 6/200
# 26/26 - 0s - loss: 0.0021 - val_loss: 0.0050 - 291ms/epoch - 11ms/step
# Epoch 7/200
# 26/26 - 0s - loss: 0.0021 - val_loss: 0.0035 - 261ms/epoch - 10ms/step
# Epoch 8/200
# 26/26 - 0s - loss: 0.0020 - val_loss: 0.0031 - 269ms/epoch - 10ms/step
# Epoch 9/200
# 26/26 - 0s - loss: 0.0019 - val_loss: 0.0068 - 324ms/epoch - 12ms/step
# Epoch 10/200
# 26/26 - 0s - loss: 0.0018 - val_loss: 0.0067 - 253ms/epoch - 10ms/step
# Epoch 11/200
# 26/26 - 0s - loss: 0.0017 - val_loss: 0.0043 - 271ms/epoch - 10ms/step
# Epoch 12/200
# 26/26 - 0s - loss: 0.0019 - val_loss: 0.0030 - 245ms/epoch - 9ms/step
# Epoch 13/200
# 26/26 - 0s - loss: 0.0015 - val_loss: 0.0025 - 304ms/epoch - 12ms/step
# Epoch 14/200
# 26/26 - 0s - loss: 0.0016 - val_loss: 0.0023 - 269ms/epoch - 10ms/step
# Epoch 15/200
# 26/26 - 0s - loss: 0.0016 - val_loss: 0.0028 - 255ms/epoch - 10ms/step
# Epoch 16/200
# 26/26 - 0s - loss: 0.0015 - val_loss: 0.0022 - 189ms/epoch - 7ms/step
# Epoch 17/200
# 26/26 - 0s - loss: 0.0014 - val_loss: 0.0021 - 251ms/epoch - 10ms/step
# Epoch 18/200
# 26/26 - 0s - loss: 0.0014 - val_loss: 0.0043 - 305ms/epoch - 12ms/step
# Epoch 19/200
# 26/26 - 0s - loss: 0.0015 - val_loss: 0.0023 - 279ms/epoch - 11ms/step
# Epoch 20/200
# 26/26 - 0s - loss: 0.0016 - val_loss: 0.0017 - 191ms/epoch - 7ms/step
# Epoch 21/200
# 26/26 - 0s - loss: 0.0014 - val_loss: 0.0021 - 182ms/epoch - 7ms/step
# Epoch 22/200
# 26/26 - 0s - loss: 0.0013 - val_loss: 0.0018 - 183ms/epoch - 7ms/step
# Epoch 23/200
# 26/26 - 0s - loss: 0.0016 - val_loss: 0.0018 - 185ms/epoch - 7ms/step
# Epoch 24/200
# 26/26 - 0s - loss: 0.0013 - val_loss: 0.0016 - 186ms/epoch - 7ms/step
# Epoch 25/200
# 26/26 - 0s - loss: 0.0011 - val_loss: 0.0016 - 187ms/epoch - 7ms/step
# Epoch 26/200
# 26/26 - 0s - loss: 0.0012 - val_loss: 0.0017 - 185ms/epoch - 7ms/step
# Epoch 27/200
# 26/26 - 0s - loss: 0.0012 - val_loss: 0.0027 - 192ms/epoch - 7ms/step
# Epoch 28/200
# 26/26 - 0s - loss: 0.0012 - val_loss: 0.0015 - 193ms/epoch - 7ms/step
# Epoch 29/200
# 26/26 - 0s - loss: 0.0011 - val_loss: 0.0016 - 195ms/epoch - 7ms/step
# Epoch 30/200
# 26/26 - 0s - loss: 0.0012 - val_loss: 0.0027 - 182ms/epoch - 7ms/step
# Epoch 31/200
# 26/26 - 0s - loss: 0.0011 - val_loss: 0.0017 - 196ms/epoch - 8ms/step
# Epoch 32/200
# 26/26 - 0s - loss: 0.0011 - val_loss: 0.0014 - 186ms/epoch - 7ms/step
# Epoch 33/200
# 26/26 - 0s - loss: 0.0011 - val_loss: 0.0028 - 191ms/epoch - 7ms/step
# Epoch 34/200
# 26/26 - 0s - loss: 0.0011 - val_loss: 0.0019 - 183ms/epoch - 7ms/step
# Epoch 35/200
# 26/26 - 0s - loss: 9.9609e-04 - val_loss: 0.0014 - 188ms/epoch - 7ms/step
# Epoch 36/200
# 26/26 - 0s - loss: 9.7491e-04 - val_loss: 0.0013 - 184ms/epoch - 7ms/step
# Epoch 37/200
# 26/26 - 0s - loss: 9.8951e-04 - val_loss: 0.0024 - 181ms/epoch - 7ms/step
# Epoch 38/200
# 26/26 - 0s - loss: 0.0010 - val_loss: 0.0024 - 179ms/epoch - 7ms/step
# Epoch 39/200
# 26/26 - 0s - loss: 0.0010 - val_loss: 0.0016 - 181ms/epoch - 7ms/step
# Epoch 40/200
# 26/26 - 0s - loss: 0.0010 - val_loss: 0.0013 - 193ms/epoch - 7ms/step
# Epoch 41/200
# 26/26 - 0s - loss: 8.6820e-04 - val_loss: 0.0013 - 186ms/epoch - 7ms/step
# Epoch 42/200
# 26/26 - 0s - loss: 9.0022e-04 - val_loss: 0.0020 - 194ms/epoch - 7ms/step
# Epoch 43/200
# 26/26 - 0s - loss: 8.7208e-04 - val_loss: 0.0016 - 177ms/epoch - 7ms/step
# Epoch 44/200
# 26/26 - 0s - loss: 8.5090e-04 - val_loss: 0.0015 - 181ms/epoch - 7ms/step
# Epoch 45/200
# 26/26 - 0s - loss: 8.6586e-04 - val_loss: 0.0018 - 191ms/epoch - 7ms/step
# Epoch 46/200
# 26/26 - 0s - loss: 8.2551e-04 - val_loss: 0.0019 - 185ms/epoch - 7ms/step
# Epoch 47/200
# 26/26 - 0s - loss: 7.8008e-04 - val_loss: 0.0018 - 181ms/epoch - 7ms/step
# Epoch 48/200
# 26/26 - 0s - loss: 8.0486e-04 - val_loss: 0.0014 - 184ms/epoch - 7ms/step
# Epoch 49/200
# 26/26 - 0s - loss: 9.5856e-04 - val_loss: 0.0012 - 197ms/epoch - 8ms/step
# Epoch 50/200
# 26/26 - 0s - loss: 7.9816e-04 - val_loss: 0.0017 - 185ms/epoch - 7ms/step
# Epoch 51/200
# 26/26 - 0s - loss: 8.7350e-04 - val_loss: 0.0012 - 195ms/epoch - 8ms/step
# Epoch 52/200
# 26/26 - 0s - loss: 8.2352e-04 - val_loss: 0.0012 - 185ms/epoch - 7ms/step
# Epoch 53/200
# 26/26 - 0s - loss: 0.0011 - val_loss: 0.0013 - 183ms/epoch - 7ms/step
# Epoch 54/200
# 26/26 - 0s - loss: 7.8166e-04 - val_loss: 0.0014 - 179ms/epoch - 7ms/step
# Epoch 55/200
# 26/26 - 0s - loss: 7.2824e-04 - val_loss: 0.0012 - 190ms/epoch - 7ms/step
# Epoch 56/200
# 26/26 - 0s - loss: 7.4989e-04 - val_loss: 0.0025 - 191ms/epoch - 7ms/step
# Epoch 57/200
# 26/26 - 0s - loss: 0.0011 - val_loss: 0.0015 - 187ms/epoch - 7ms/step
# Epoch 58/200
# 26/26 - 0s - loss: 7.9850e-04 - val_loss: 0.0012 - 186ms/epoch - 7ms/step
# Epoch 59/200
# 26/26 - 0s - loss: 8.2005e-04 - val_loss: 0.0012 - 193ms/epoch - 7ms/step
# Epoch 60/200
# 26/26 - 0s - loss: 7.2019e-04 - val_loss: 0.0012 - 192ms/epoch - 7ms/step
# Epoch 61/200
# 26/26 - 0s - loss: 7.8736e-04 - val_loss: 0.0020 - 202ms/epoch - 8ms/step
# Epoch 62/200
# 26/26 - 0s - loss: 0.0011 - val_loss: 0.0012 - 190ms/epoch - 7ms/step
# Epoch 63/200
# 26/26 - 0s - loss: 7.9860e-04 - val_loss: 0.0012 - 187ms/epoch - 7ms/step
# Epoch 64/200
# 26/26 - 0s - loss: 7.1374e-04 - val_loss: 0.0012 - 190ms/epoch - 7ms/step
# Epoch 65/200
# 26/26 - 0s - loss: 8.8447e-04 - val_loss: 0.0011 - 185ms/epoch - 7ms/step
# Epoch 66/200
# 26/26 - 0s - loss: 7.1613e-04 - val_loss: 0.0014 - 288ms/epoch - 11ms/step
# Epoch 67/200
# 26/26 - 0s - loss: 6.7869e-04 - val_loss: 0.0015 - 244ms/epoch - 9ms/step
# Epoch 68/200
# 26/26 - 0s - loss: 7.2457e-04 - val_loss: 0.0011 - 252ms/epoch - 10ms/step
# Epoch 69/200
# 26/26 - 0s - loss: 7.3074e-04 - val_loss: 0.0011 - 253ms/epoch - 10ms/step
# Epoch 70/200
# 26/26 - 0s - loss: 6.4212e-04 - val_loss: 0.0010 - 254ms/epoch - 10ms/step
# Epoch 71/200
# 26/26 - 0s - loss: 8.1099e-04 - val_loss: 0.0016 - 245ms/epoch - 9ms/step
# Epoch 72/200
# 26/26 - 0s - loss: 7.5983e-04 - val_loss: 0.0010 - 251ms/epoch - 10ms/step
# Epoch 73/200
# 26/26 - 0s - loss: 6.1109e-04 - val_loss: 0.0011 - 249ms/epoch - 10ms/step
# Epoch 74/200
# 26/26 - 0s - loss: 8.0060e-04 - val_loss: 0.0013 - 271ms/epoch - 10ms/step
# Epoch 75/200
# 26/26 - 0s - loss: 6.4666e-04 - val_loss: 0.0016 - 254ms/epoch - 10ms/step
# Epoch 76/200
# 26/26 - 0s - loss: 6.2785e-04 - val_loss: 0.0012 - 287ms/epoch - 11ms/step
# Epoch 77/200
# 26/26 - 0s - loss: 7.6110e-04 - val_loss: 0.0011 - 252ms/epoch - 10ms/step
# Epoch 78/200
# 26/26 - 0s - loss: 7.0010e-04 - val_loss: 9.8897e-04 - 310ms/epoch - 12ms/step
# Epoch 79/200
# 26/26 - 0s - loss: 6.6059e-04 - val_loss: 9.8403e-04 - 216ms/epoch - 8ms/step
# Epoch 80/200
# 26/26 - 0s - loss: 6.6479e-04 - val_loss: 0.0011 - 189ms/epoch - 7ms/step
# Epoch 81/200
# 26/26 - 0s - loss: 7.1641e-04 - val_loss: 0.0015 - 184ms/epoch - 7ms/step
# Epoch 82/200
# 26/26 - 0s - loss: 6.6000e-04 - val_loss: 9.5642e-04 - 188ms/epoch - 7ms/step
# Epoch 83/200
# 26/26 - 0s - loss: 6.3438e-04 - val_loss: 0.0011 - 194ms/epoch - 7ms/step
# Epoch 84/200
# 26/26 - 0s - loss: 6.2765e-04 - val_loss: 0.0014 - 189ms/epoch - 7ms/step
# Epoch 85/200
# 26/26 - 0s - loss: 6.9487e-04 - val_loss: 9.8911e-04 - 182ms/epoch - 7ms/step
# Epoch 86/200
# 26/26 - 0s - loss: 6.5424e-04 - val_loss: 9.4808e-04 - 185ms/epoch - 7ms/step
# Epoch 87/200
# 26/26 - 0s - loss: 6.6911e-04 - val_loss: 0.0014 - 181ms/epoch - 7ms/step
# Epoch 88/200
# 26/26 - 0s - loss: 7.5030e-04 - val_loss: 9.8916e-04 - 191ms/epoch - 7ms/step
# Epoch 89/200
# 26/26 - 0s - loss: 6.6181e-04 - val_loss: 0.0013 - 188ms/epoch - 7ms/step
# Epoch 90/200
# 26/26 - 0s - loss: 6.5742e-04 - val_loss: 0.0013 - 179ms/epoch - 7ms/step
# Epoch 91/200
# 26/26 - 0s - loss: 6.5722e-04 - val_loss: 9.0523e-04 - 186ms/epoch - 7ms/step
# Epoch 92/200
# 26/26 - 0s - loss: 6.4230e-04 - val_loss: 0.0013 - 185ms/epoch - 7ms/step
# Epoch 93/200
# 26/26 - 0s - loss: 7.6726e-04 - val_loss: 9.7152e-04 - 211ms/epoch - 8ms/step
# Epoch 94/200
# 26/26 - 0s - loss: 6.4278e-04 - val_loss: 0.0011 - 181ms/epoch - 7ms/step
# Epoch 95/200
# 26/26 - 0s - loss: 6.1475e-04 - val_loss: 8.7643e-04 - 184ms/epoch - 7ms/step
# Epoch 96/200
# 26/26 - 0s - loss: 6.4973e-04 - val_loss: 0.0011 - 182ms/epoch - 7ms/step
# Epoch 97/200
# 26/26 - 0s - loss: 6.4578e-04 - val_loss: 8.7213e-04 - 187ms/epoch - 7ms/step
# Epoch 98/200
# 26/26 - 0s - loss: 6.4644e-04 - val_loss: 8.6064e-04 - 177ms/epoch - 7ms/step
# Epoch 99/200
# 26/26 - 0s - loss: 5.9000e-04 - val_loss: 0.0012 - 194ms/epoch - 7ms/step
# Epoch 100/200
# 26/26 - 0s - loss: 6.3185e-04 - val_loss: 8.7030e-04 - 187ms/epoch - 7ms/step
# Epoch 101/200
# 26/26 - 0s - loss: 6.3908e-04 - val_loss: 0.0011 - 184ms/epoch - 7ms/step
# Epoch 102/200
# 26/26 - 0s - loss: 6.2614e-04 - val_loss: 8.4192e-04 - 179ms/epoch - 7ms/step
# Epoch 103/200
# 26/26 - 0s - loss: 6.9662e-04 - val_loss: 0.0011 - 184ms/epoch - 7ms/step
# Epoch 104/200
# 26/26 - 0s - loss: 5.9935e-04 - val_loss: 0.0010 - 199ms/epoch - 8ms/step
# Epoch 105/200
# 26/26 - 0s - loss: 6.0941e-04 - val_loss: 0.0011 - 178ms/epoch - 7ms/step
# Epoch 106/200
# 26/26 - 0s - loss: 5.8974e-04 - val_loss: 8.1074e-04 - 182ms/epoch - 7ms/step
# Epoch 107/200
# 26/26 - 0s - loss: 6.0838e-04 - val_loss: 9.6022e-04 - 178ms/epoch - 7ms/step
# Epoch 108/200
# 26/26 - 0s - loss: 5.9750e-04 - val_loss: 8.6053e-04 - 189ms/epoch - 7ms/step
# Epoch 109/200
# 26/26 - 0s - loss: 6.5235e-04 - val_loss: 8.0376e-04 - 186ms/epoch - 7ms/step
# Epoch 110/200
# 26/26 - 0s - loss: 5.3738e-04 - val_loss: 8.3411e-04 - 193ms/epoch - 7ms/step
# Epoch 111/200
# 26/26 - 0s - loss: 5.8889e-04 - val_loss: 7.8764e-04 - 177ms/epoch - 7ms/step
# Epoch 112/200
# 26/26 - 0s - loss: 5.6088e-04 - val_loss: 8.9774e-04 - 193ms/epoch - 7ms/step
# Epoch 113/200
# 26/26 - 0s - loss: 5.7977e-04 - val_loss: 7.7120e-04 - 186ms/epoch - 7ms/step
# Epoch 114/200
# 26/26 - 0s - loss: 5.6927e-04 - val_loss: 0.0010 - 193ms/epoch - 7ms/step
# Epoch 115/200
# 26/26 - 0s - loss: 5.9737e-04 - val_loss: 7.6094e-04 - 188ms/epoch - 7ms/step
# Epoch 116/200
# 26/26 - 0s - loss: 6.2751e-04 - val_loss: 9.7968e-04 - 187ms/epoch - 7ms/step
# Epoch 117/200
# 26/26 - 0s - loss: 6.0829e-04 - val_loss: 0.0012 - 178ms/epoch - 7ms/step
# Epoch 118/200
# 26/26 - 0s - loss: 5.6701e-04 - val_loss: 7.4113e-04 - 184ms/epoch - 7ms/step
# Epoch 119/200
# 26/26 - 0s - loss: 5.7518e-04 - val_loss: 8.0533e-04 - 177ms/epoch - 7ms/step
# Epoch 120/200
# 26/26 - 0s - loss: 7.0379e-04 - val_loss: 0.0016 - 228ms/epoch - 9ms/step
# Epoch 121/200
# 26/26 - 0s - loss: 6.0682e-04 - val_loss: 7.4547e-04 - 182ms/epoch - 7ms/step
# Epoch 122/200
# 26/26 - 0s - loss: 5.0191e-04 - val_loss: 0.0010 - 186ms/epoch - 7ms/step
# Epoch 123/200
# 26/26 - 0s - loss: 5.2514e-04 - val_loss: 8.4018e-04 - 191ms/epoch - 7ms/step
# Epoch 124/200
# 26/26 - 0s - loss: 5.3802e-04 - val_loss: 0.0014 - 186ms/epoch - 7ms/step
# Epoch 125/200
# 26/26 - 0s - loss: 4.9993e-04 - val_loss: 6.9287e-04 - 185ms/epoch - 7ms/step
# Epoch 126/200
# 26/26 - 0s - loss: 6.3074e-04 - val_loss: 7.2836e-04 - 197ms/epoch - 8ms/step
# Epoch 127/200
# 26/26 - 0s - loss: 4.6585e-04 - val_loss: 7.3914e-04 - 177ms/epoch - 7ms/step
# Epoch 128/200
# 26/26 - 0s - loss: 5.2516e-04 - val_loss: 9.0845e-04 - 186ms/epoch - 7ms/step
# Epoch 129/200
# 26/26 - 0s - loss: 5.8925e-04 - val_loss: 0.0011 - 182ms/epoch - 7ms/step
# Epoch 130/200
# 26/26 - 0s - loss: 4.8196e-04 - val_loss: 0.0011 - 179ms/epoch - 7ms/step
# Epoch 131/200
# 26/26 - 0s - loss: 5.2294e-04 - val_loss: 7.8246e-04 - 273ms/epoch - 10ms/step
# Epoch 132/200
# 26/26 - 0s - loss: 5.5302e-04 - val_loss: 7.2567e-04 - 267ms/epoch - 10ms/step
# Epoch 133/200
# 26/26 - 0s - loss: 6.6810e-04 - val_loss: 0.0011 - 295ms/epoch - 11ms/step
# Epoch 134/200
# 26/26 - 0s - loss: 5.1719e-04 - val_loss: 0.0010 - 306ms/epoch - 12ms/step
# Epoch 135/200
# 26/26 - 0s - loss: 4.9867e-04 - val_loss: 6.7929e-04 - 255ms/epoch - 10ms/step
# Epoch 136/200
# 26/26 - 0s - loss: 5.4163e-04 - val_loss: 6.2516e-04 - 238ms/epoch - 9ms/step
# Epoch 137/200
# 26/26 - 0s - loss: 6.4762e-04 - val_loss: 0.0012 - 291ms/epoch - 11ms/step
# Epoch 138/200
# 26/26 - 0s - loss: 6.6202e-04 - val_loss: 7.0694e-04 - 299ms/epoch - 12ms/step
# Epoch 139/200
# 26/26 - 0s - loss: 5.0543e-04 - val_loss: 7.2568e-04 - 290ms/epoch - 11ms/step
# Epoch 140/200
# 26/26 - 0s - loss: 5.3435e-04 - val_loss: 6.0079e-04 - 247ms/epoch - 10ms/step
# Epoch 141/200
# 26/26 - 0s - loss: 5.0300e-04 - val_loss: 6.3713e-04 - 296ms/epoch - 11ms/step
# Epoch 142/200
# 26/26 - 0s - loss: 4.9391e-04 - val_loss: 7.2759e-04 - 304ms/epoch - 12ms/step
# Epoch 143/200
# 26/26 - 0s - loss: 5.3138e-04 - val_loss: 6.3801e-04 - 224ms/epoch - 9ms/step
# Epoch 144/200
# 26/26 - 0s - loss: 4.5083e-04 - val_loss: 0.0013 - 189ms/epoch - 7ms/step
# Epoch 145/200
# 26/26 - 0s - loss: 4.9513e-04 - val_loss: 5.9772e-04 - 191ms/epoch - 7ms/step
# Epoch 146/200
# 26/26 - 0s - loss: 6.7926e-04 - val_loss: 7.2069e-04 - 185ms/epoch - 7ms/step
# Epoch 147/200
# 26/26 - 0s - loss: 5.6426e-04 - val_loss: 6.7509e-04 - 191ms/epoch - 7ms/step
# Epoch 148/200
# 26/26 - 0s - loss: 4.5792e-04 - val_loss: 6.2234e-04 - 186ms/epoch - 7ms/step
# Epoch 149/200
# 26/26 - 0s - loss: 4.2562e-04 - val_loss: 6.1336e-04 - 181ms/epoch - 7ms/step
# Epoch 150/200
# 26/26 - 0s - loss: 4.7175e-04 - val_loss: 5.8992e-04 - 190ms/epoch - 7ms/step
# Epoch 151/200
# 26/26 - 0s - loss: 4.7561e-04 - val_loss: 6.0592e-04 - 189ms/epoch - 7ms/step
# Epoch 152/200
# 26/26 - 0s - loss: 5.0253e-04 - val_loss: 5.5821e-04 - 205ms/epoch - 8ms/step
# Epoch 153/200
# 26/26 - 0s - loss: 4.7824e-04 - val_loss: 5.5639e-04 - 194ms/epoch - 7ms/step
# Epoch 154/200
# 26/26 - 0s - loss: 5.8044e-04 - val_loss: 9.1092e-04 - 190ms/epoch - 7ms/step
# Epoch 155/200
# 26/26 - 0s - loss: 6.2607e-04 - val_loss: 6.4422e-04 - 189ms/epoch - 7ms/step
# Epoch 156/200
# 26/26 - 0s - loss: 4.1950e-04 - val_loss: 5.9537e-04 - 190ms/epoch - 7ms/step
# Epoch 157/200
# 26/26 - 0s - loss: 4.4015e-04 - val_loss: 5.4166e-04 - 192ms/epoch - 7ms/step
# Epoch 158/200
# 26/26 - 0s - loss: 4.8044e-04 - val_loss: 5.3520e-04 - 181ms/epoch - 7ms/step
# Epoch 159/200
# 26/26 - 0s - loss: 4.5863e-04 - val_loss: 5.3461e-04 - 192ms/epoch - 7ms/step
# Epoch 160/200
# 26/26 - 0s - loss: 5.3873e-04 - val_loss: 6.3521e-04 - 191ms/epoch - 7ms/step
# Epoch 161/200
# 26/26 - 0s - loss: 4.5187e-04 - val_loss: 8.0936e-04 - 182ms/epoch - 7ms/step
# Epoch 162/200
# 26/26 - 0s - loss: 5.0231e-04 - val_loss: 5.6361e-04 - 186ms/epoch - 7ms/step
# Epoch 163/200
# 26/26 - 0s - loss: 4.6860e-04 - val_loss: 5.5663e-04 - 181ms/epoch - 7ms/step
# Epoch 164/200
# 26/26 - 0s - loss: 4.5987e-04 - val_loss: 5.3145e-04 - 189ms/epoch - 7ms/step
# Epoch 165/200
# 26/26 - 0s - loss: 4.2263e-04 - val_loss: 8.0548e-04 - 188ms/epoch - 7ms/step
# Epoch 166/200
# 26/26 - 0s - loss: 4.9230e-04 - val_loss: 5.3145e-04 - 183ms/epoch - 7ms/step
# Epoch 167/200
# 26/26 - 0s - loss: 4.6134e-04 - val_loss: 5.4730e-04 - 179ms/epoch - 7ms/step
# Epoch 168/200
# 26/26 - 0s - loss: 4.3002e-04 - val_loss: 7.9800e-04 - 192ms/epoch - 7ms/step
# Epoch 169/200
# 26/26 - 0s - loss: 5.3809e-04 - val_loss: 6.2593e-04 - 185ms/epoch - 7ms/step
# Epoch 170/200
# 26/26 - 0s - loss: 4.6533e-04 - val_loss: 5.7800e-04 - 198ms/epoch - 8ms/step
# Epoch 171/200
# 26/26 - 0s - loss: 4.5407e-04 - val_loss: 5.6095e-04 - 189ms/epoch - 7ms/step
# Epoch 172/200
# 26/26 - 0s - loss: 4.5152e-04 - val_loss: 6.6714e-04 - 181ms/epoch - 7ms/step
# Epoch 173/200
# 26/26 - 0s - loss: 4.8288e-04 - val_loss: 0.0012 - 196ms/epoch - 8ms/step
# Epoch 174/200
# 26/26 - 0s - loss: 4.1761e-04 - val_loss: 6.3705e-04 - 185ms/epoch - 7ms/step
# Epoch 175/200
# 26/26 - 0s - loss: 4.7328e-04 - val_loss: 5.1001e-04 - 179ms/epoch - 7ms/step
# Epoch 176/200
# 26/26 - 0s - loss: 5.7534e-04 - val_loss: 0.0011 - 184ms/epoch - 7ms/step
# Epoch 177/200
# 26/26 - 0s - loss: 4.8707e-04 - val_loss: 6.8055e-04 - 188ms/epoch - 7ms/step
# Epoch 178/200
# 26/26 - 0s - loss: 6.0346e-04 - val_loss: 5.0512e-04 - 195ms/epoch - 7ms/step
# Epoch 179/200
# 26/26 - 0s - loss: 4.7503e-04 - val_loss: 5.2683e-04 - 186ms/epoch - 7ms/step
# Epoch 180/200
# 26/26 - 0s - loss: 4.2653e-04 - val_loss: 7.9112e-04 - 182ms/epoch - 7ms/step
# Epoch 181/200
# 26/26 - 0s - loss: 4.4506e-04 - val_loss: 5.2202e-04 - 184ms/epoch - 7ms/step
# Epoch 182/200
# 26/26 - 0s - loss: 3.8650e-04 - val_loss: 6.2390e-04 - 178ms/epoch - 7ms/step
# Epoch 183/200
# 26/26 - 0s - loss: 4.1523e-04 - val_loss: 5.5821e-04 - 183ms/epoch - 7ms/step
# Epoch 184/200
# 26/26 - 0s - loss: 4.4878e-04 - val_loss: 5.9808e-04 - 194ms/epoch - 7ms/step
# Epoch 185/200
# 26/26 - 0s - loss: 3.8972e-04 - val_loss: 5.1318e-04 - 186ms/epoch - 7ms/step
# Epoch 186/200
# 26/26 - 0s - loss: 4.5985e-04 - val_loss: 5.4914e-04 - 179ms/epoch - 7ms/step
# Epoch 187/200
# 26/26 - 0s - loss: 4.5495e-04 - val_loss: 5.5235e-04 - 183ms/epoch - 7ms/step
# Epoch 188/200
# 26/26 - 0s - loss: 4.4220e-04 - val_loss: 6.2425e-04 - 184ms/epoch - 7ms/step
# Epoch 189/200
# 26/26 - 0s - loss: 4.5835e-04 - val_loss: 6.8331e-04 - 185ms/epoch - 7ms/step
# Epoch 190/200
# 26/26 - 0s - loss: 4.3462e-04 - val_loss: 4.8746e-04 - 184ms/epoch - 7ms/step
# Epoch 191/200
# 26/26 - 0s - loss: 4.5576e-04 - val_loss: 9.9965e-04 - 172ms/epoch - 7ms/step
# Epoch 192/200
# 26/26 - 0s - loss: 4.2392e-04 - val_loss: 7.2625e-04 - 175ms/epoch - 7ms/step
# Epoch 193/200
# 26/26 - 0s - loss: 4.8471e-04 - val_loss: 5.0999e-04 - 194ms/epoch - 7ms/step
# Epoch 194/200
# 26/26 - 0s - loss: 4.6442e-04 - val_loss: 7.1365e-04 - 172ms/epoch - 7ms/step
# Epoch 195/200
# 26/26 - 0s - loss: 4.3599e-04 - val_loss: 5.9907e-04 - 257ms/epoch - 10ms/step
# Epoch 196/200
# 26/26 - 0s - loss: 4.3440e-04 - val_loss: 8.3048e-04 - 263ms/epoch - 10ms/step
# Epoch 197/200
# 26/26 - 0s - loss: 4.0365e-04 - val_loss: 5.7496e-04 - 300ms/epoch - 12ms/step
# Epoch 198/200
# 26/26 - 0s - loss: 4.3148e-04 - val_loss: 6.2711e-04 - 273ms/epoch - 11ms/step
# Epoch 199/200
# 26/26 - 0s - loss: 4.2849e-04 - val_loss: 4.9760e-04 - 263ms/epoch - 10ms/step
# Epoch 200/200
# 26/26 - 0s - loss: 3.9702e-04 - val_loss: 4.9796e-04 - 310ms/epoch - 12ms/step

# %% [markdown]
# Dividing Test values into groups

# %% [markdown]
# Prediction

# %%
predicted_price = algo.predict(x_test)
predicted_price = sc.inverse_transform(predicted_price)
# Out:
# 8/8 [==============================] - 1s 5ms/step

# %%
df.reset_index(inplace=True)
plt.plot(df.loc[:t_size+1,'Date'],df.loc[:t_size+1,'Open'], color='green',label="Train data")
plt.plot(df.loc[t_size:, 'Date'],data_test, color = 'red', label = 'Test Data')
plt.plot(df.loc[t_size:, 'Date'],predicted_price, color = 'blue', label = 'Predicted Data')
plt.xticks(np.arange(0,df.shape[0],250))
plt.title('Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel('Stock Price')
plt.legend()
plt.show()

# %%
plt.plot(df.loc[:t_size+1,'Date'],df.loc[:t_size+1,'Open'], color='green',label="Train data")

plt.xticks(np.arange(0,df.shape[0],250))
plt.title('Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel('Stock Price')
plt.legend()
plt.show()

# %%
plt.plot(df.loc[t_size:, 'Date'],data_test, color = 'red', label = 'Test Data')
plt.plot(df.loc[t_size:, 'Date'],predicted_price, color = 'blue', label = 'Predicted Data')
plt.xticks(np.arange(0,x_test.shape[0],50))
plt.title('Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel('Stock Price')
plt.legend()
plt.show()

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error
import numpy as np

mae = mean_absolute_error(data_test,predicted_price)

mse = mean_squared_error(data_test, predicted_price)

rmse = np.sqrt(mse)

print(f'Mean Absolute Error (MAE): {mae:.2f}')
print(f'Mean Squared Error (MSE): {mse:.2f}')
print(f'Root Mean Squared Error (RMSE): {rmse:.2f}')
# Out:
# Mean Absolute Error (MAE): 5.54
# Mean Squared Error (MSE): 50.59
# Root Mean Squared Error (RMSE): 7.11

# %% [markdown]
# Predict Future

# %%
test2=data_test.copy()
for i in range(f_size):
  X=test2[-w_size:]
  X=X.reshape(w_size,1)
  X=sc.fit_transform(X)

  X=np.reshape(X,(1,w_size,1))

  close=algo.predict(X)
  y=sc.inverse_transform(close)

  test2=np.append(test2, y)
# Out:
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step

# %%
from datetime import datetime, timedelta
x=df.loc[-1:, 'Date']
day=x[len(x)-1]
date_obj = datetime.strptime(day, '%Y-%m-%d')
start_date = date_obj
date_list = [(start_date + timedelta(days=i)).strftime('%Y-%m-%d') for i in range(f_size)]

# %%
forcasted_data=test2[-f_size:]
plt.plot(date_list,forcasted_data,color='yellow', label="Future data")
plt.xticks(np.arange(0,len(forcasted_data),10))
plt.show()

# %%
plt.plot(df.loc[:t_size,'Date'],df.loc[:t_size,'Open'], color='green',label="Train data")
plt.plot(df.loc[t_size:, 'Date'],data_test, color = 'red', label = 'Test Data')
plt.plot(df.loc[t_size:, 'Date'],predicted_price, color = 'blue', label = 'Predicted Data')
plt.plot(date_list,forcasted_data,color='yellow', label="Future data")
plt.xticks(np.arange(0,df.shape[0],250))
plt.title('Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel('Stock Price')
plt.legend()
plt.show()

# %%
plt.plot(df.loc[t_size:, 'Date'],data_test, color = 'red', label = 'Test Data')
plt.plot(df.loc[t_size:, 'Date'],predicted_price, color = 'blue', label = 'Predicted Data')
plt.plot(date_list,forcasted_data,color='yellow', label="Future data")
plt.xticks(np.arange(0,x_test.shape[0],50))
plt.title('Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel('Stock Price')
plt.legend()
plt.show()
